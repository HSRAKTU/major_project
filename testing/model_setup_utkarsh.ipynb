# %%
# -----------------------------
# 1. Imports and Seed Setup
# -----------------------------
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
import warnings
warnings.filterwarnings("ignore")

# Reproducibility
torch.manual_seed(42)
np.random.seed(42)

# %%
# -----------------------------
# 2. Enhanced PointNet2D
# -----------------------------
class PointNet2D(nn.Module):
    def __init__(self, input_dim=2, emb_dim=256):
        super(PointNet2D, self).__init__()
        # self.mlp = nn.Sequential(
        #     nn.Conv1d(input_dim, 64, kernel_size=1),
        #     nn.BatchNorm1d(64),
        #     nn.ReLU(),
        #     nn.Conv1d(64, 128, kernel_size=1),
        #     nn.BatchNorm1d(128),
        #     nn.ReLU(),
        #     nn.Conv1d(128, emb_dim, kernel_size=1),
        #     nn.BatchNorm1d(emb_dim),
        #     nn.ReLU()
        # )

        self.mlp = nn.Sequential(
                nn.Conv1d(input_dim, 64, 1),
                nn.BatchNorm1d(64),
                nn.ReLU(),
                nn.Conv1d(64, 128, 1),
                nn.BatchNorm1d(128),
                nn.ReLU(),
                nn.Conv1d(128, 256, 1),
                nn.BatchNorm1d(256),
                nn.ReLU(),
                nn.Conv1d(256, emb_dim, 1),
                nn.BatchNorm1d(emb_dim),
                nn.ReLU()
            )

    def forward(self, x, mask=None):
        # x: (B, N, 2) -> (B, 2, N)
        x = x.transpose(1, 2)
        features = self.mlp(x)  # (B, emb_dim, N)

        if mask is not None:
            mask = mask.unsqueeze(1)  # (B, 1, N)
            features = features.masked_fill(mask == 0, -1e2)

        embedding = torch.max(features, dim=2)[0]  # (B, emb_dim)
        return embedding

# %%
# %%
# -----------------------------
# 2A. DGCNN2D Shape Learner (Corrected)
# -----------------------------
import torch.nn.functional as F

def knn(x, k):
    B, N, D = x.shape
    # Compute pairwise Euclidean distances using vectorization
    x_inner = -2 * torch.matmul(x, x.transpose(2, 1))  # (B, N, N)
    x_square = torch.sum(x ** 2, dim=2, keepdim=True)  # (B, N, 1)
    dist = x_square + x_inner + x_square.transpose(2, 1)  # (B, N, N)
    _, idx = dist.topk(k=k, dim=-1, largest=False)
    return idx  # (B, N, k)

def get_graph_feature(x, k=10):
    B, N, D = x.size()
    idx = knn(x, k=k)  # (B, N, k)

    idx_base = torch.arange(0, B, device=x.device).view(-1, 1, 1) * N
    idx = idx + idx_base
    idx = idx.view(-1)  # (B * N * k)

    x_flat = x.view(B * N, D)
    neighbors = x_flat[idx].view(B, N, k, D)  # (B, N, k, D)
    x_central = x.view(B, N, 1, D).expand(-1, -1, k, -1)  # (B, N, k, D)

    edge_feature = torch.cat((x_central, neighbors - x_central), dim=3)  # (B, N, k, 2D)
    return edge_feature.permute(0, 3, 1, 2)  # (B, 2D, N, k)

class DGCNN2D(nn.Module):
    def __init__(self, input_dim=2, emb_dim=256, k=10):
        super(DGCNN2D, self).__init__()
        self.k = k

        self.conv1 = nn.Sequential(
            nn.Conv2d(input_dim * 2, 64, kernel_size=1),
            nn.BatchNorm2d(64),
            nn.ReLU()
        )

        self.conv2 = nn.Sequential(
            nn.Conv2d(64 * 2, 128, kernel_size=1),
            nn.BatchNorm2d(128),
            nn.ReLU()
        )

        self.fc = nn.Sequential(
            nn.Linear(128, emb_dim),
            nn.LayerNorm(emb_dim),  # ✅ Works even with batch size = 1
            nn.ReLU()
        )




    def forward(self, x, mask=None):
        # x: (B, N, 2)
        x_feat = get_graph_feature(x, k=self.k)            # → (B, 4, N, k)
        x1 = self.conv1(x_feat).max(dim=-1)[0]             # → (B, 64, N)

        x2_feat = get_graph_feature(x1.transpose(1, 2), k=self.k)  # (B, 128, N, k)
        x2 = self.conv2(x2_feat).max(dim=-1)[0]            # → (B, 128, N)

        if mask is not None:
            mask = mask.unsqueeze(1)                       # (B, 1, N)
            x2 = x2.masked_fill(mask == 0, -1e9)

        x_out = torch.max(x2, dim=2)[0]                    # → (B, 128)
        return self.fc(x_out)                              # → (B, emb_dim)

# %%
# -----------------------------
# 3. LSTM Slice Encoder
# -----------------------------
class LSTMSliceEncoder(nn.Module):
    # def __init__(self, input_dim=256, hidden_dim=256, num_layers=4, bidirectional=True):
        # super().__init__()
        # self.lstm = nn.LSTM(
        #     input_size=input_dim,
        #     hidden_size=hidden_dim,
        #     num_layers=num_layers,
        #     batch_first=True,
        #     bidirectional=bidirectional
        # )
    def __init__(self, input_dim=512, hidden_dim=512, num_layers=4, bidirectional=True):
        super().__init__()
        self.lstm = nn.LSTM(
            input_size=input_dim,
            hidden_size=hidden_dim,
            num_layers=num_layers,
            batch_first=True,
            bidirectional=bidirectional,
            dropout=0.2   # Dropout between layers
        )

    def forward(self, x):
        # x: (B, S, D)
        _, (h_n, _) = self.lstm(x)
        if self.lstm.bidirectional:
            return torch.cat((h_n[-2], h_n[-1]), dim=-1)  # (B, 2H)
        else:
            return h_n[-1]  # (B, H)

# %%
# -----------------------------
# 4. Cd Regressor MLP
# -----------------------------
# class CdRegressor(nn.Module):
#     def __init__(self, input_dim):
#         super().__init__()
#         self.net = nn.Sequential(
#             nn.Linear(input_dim, 128),
#             nn.ReLU(),
#             nn.Dropout(0.3),
#             nn.Linear(128, 64),
#             nn.ReLU(),
#             nn.Linear(64, 1)
#         )

#     def forward(self, x):
#         return self.net(x).squeeze(1)
class CdRegressor(nn.Module):
    def __init__(self, input_dim=1024):  # 512 * 2 from BiLSTM
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(256, 64),
            nn.ReLU(),
            nn.Linear(64, 1)
        )

    def forward(self, x):
        return self.net(x).squeeze(1)

# %%
# -----------------------------
# 5. Full Model Assembly
# -----------------------------
class CdPredictorNet(nn.Module):
    def __init__(self, pointnet, lstm_encoder, regressor):
        super().__init__()
        self.pointnet = pointnet
        self.lstm_encoder = lstm_encoder
        self.regressor = regressor
    
    
    # thisis for pointnet2d
    def forward(self, slices, point_mask, slice_mask):
        B, S, N, D = slices.shape
        flat_slices = slices.view(B * S, N, D)
        flat_mask = point_mask.view(B * S, N)

        slice_embs = self.pointnet(flat_slices, flat_mask)  # (B*S, 256)
        slice_embs = slice_embs.view(B, S, -1)  # (B, 80, 256)

        car_emb = self.lstm_encoder(slice_embs)  # (B, 512 if bidirectional)
        return self.regressor(car_emb)

# %%
# -----------------------------
# 6. Dataset Loader
# -----------------------------
class CarSlicesDataset(torch.utils.data.Dataset):
    def __init__(self, ids_txt, npz_dir, csv_path, max_cars=None):
        self.car_ids = [line.strip() for line in open(ids_txt)]
        if max_cars:
            self.car_ids = self.car_ids[:max_cars]
        self.npz_dir = npz_dir
        self.df = pd.read_csv(csv_path)

    def __len__(self):
        return len(self.car_ids)

    def __getitem__(self, idx):
        car_id = self.car_ids[idx]
        data = np.load(os.path.join(self.npz_dir, f"{car_id}_axis-x.npz"))
        slices = torch.tensor(data["slices"], dtype=torch.float32)  # (80, 6500, 2)
        point_mask = torch.tensor(data["point_mask"], dtype=torch.float32)  # (80, 6500)
        slice_mask = torch.tensor(data["slice_mask"], dtype=torch.float32)  # (80,)
        cd_value = self.df[self.df["Design"] == car_id]["Average Cd"].values[0]
        return slices, point_mask, slice_mask, torch.tensor(cd_value, dtype=torch.float32)

# %%
import os
import glob
import torch
import torch.nn as nn
from tqdm import tqdm

def train_model(resume=True, num_epochs=50, max_cars=2000,
                checkpoint_dir="../outputs/checkpoints", early_stopping_patience=5):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    # Initialize model components
    pointnet = PointNet2D()
    # pointnet = DGCNN2D(input_dim=2, emb_dim=256)
    lstm_encoder = LSTMSliceEncoder()
    regressor = CdRegressor(input_dim=1024)
    model = CdPredictorNet(pointnet, lstm_encoder, regressor).to(device)

    optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
    loss_fn = nn.SmoothL1Loss()  # Replaced with more stable alternative to MSE

    os.makedirs(checkpoint_dir, exist_ok=True)
    start_epoch = 1
    best_loss = float("inf")
    patience_counter = 0
    epoch_losses = []

    # Resume from checkpoint if exists
    if resume:
        checkpoints = sorted(glob.glob(f"{checkpoint_dir}/epoch_*_loss*.pt"))
        if checkpoints:
            latest_ckpt = checkpoints[-1]
            print(f"🔄 Resuming from checkpoint: {latest_ckpt}")
            state = torch.load(latest_ckpt, map_location=device)
            model.load_state_dict(state['model'])
            optimizer.load_state_dict(state['optimizer'])
            start_epoch = state['epoch'] + 1
            epoch_losses = state.get('epoch_losses', [])
            best_loss = min(epoch_losses) if epoch_losses else float("inf")
        else:
            print("⏩ No previous checkpoint found, starting fresh.")

    # Load dataset
    dataset = CarSlicesDataset(
        ids_txt="../data/subset_dir/train_design_ids.txt",
        npz_dir="../outputs/pad_masked_slices",
        csv_path="../data/DrivAerNetPlusPlus_Drag_8k_cleaned.csv",
        max_cars=max_cars
    )
    dataloader = torch.utils.data.DataLoader(dataset, batch_size=2, shuffle=True , pin_memory=True)

    try:
        for epoch in range(start_epoch, num_epochs + 1):
            model.train()
            total_loss = 0.0
            pbar = tqdm(dataloader, desc=f"Epoch {epoch}", unit="batch")

            for slices, point_mask, slice_mask, cd_gt in pbar:
                slices = slices.to(device)
                point_mask = point_mask.to(device)
                cd_gt = cd_gt.to(device)

                pred = model(slices, point_mask, slice_mask)
                loss = loss_fn(pred, cd_gt)

                optimizer.zero_grad()
                loss.backward()
                optimizer.step()

                batch_loss = loss.item() * slices.size(0)
                total_loss += batch_loss
                pbar.set_postfix(loss=batch_loss / slices.size(0))

            avg_loss = total_loss / len(dataloader.dataset)
            epoch_losses.append(avg_loss)
            print(f"✅ Epoch {epoch}: Avg SmoothL1 Loss = {avg_loss:.7f}")

            # Save checkpoint
            ckpt_path = os.path.join(checkpoint_dir, f"epoch_{epoch:02d}_loss_{avg_loss:.4f}.pt")
            torch.save({
                'epoch': epoch,
                'model': model.state_dict(),
                'optimizer': optimizer.state_dict(),
                'epoch_losses': epoch_losses
            }, ckpt_path)
            print(f"💾 Checkpoint saved: {ckpt_path}")

            # Early stopping
            if avg_loss < best_loss:
                best_loss = avg_loss
                patience_counter = 0
            else:
                patience_counter += 1
                if patience_counter >= early_stopping_patience:
                    print(f"🛑 Early stopping triggered at epoch {epoch}.")
                    break

    except KeyboardInterrupt:
        print("\n⛔ Interrupted by user. Saving last checkpoint...")
        torch.save({
            'epoch': epoch,
            'model': model.state_dict(),
            'optimizer': optimizer.state_dict(),
            'epoch_losses': epoch_losses
        }, os.path.join(checkpoint_dir, f"interrupted_epoch_{epoch}.pt"))
        print("🧷 Last checkpoint saved. Safe to resume later.")

    return model, epoch_losses

# %%
import os
import glob
import torch
import json
import matplotlib.pyplot as plt
import seaborn as sns

def analyze_all_checkpoints(model=None, checkpoint_dir="../outputs/checkpoints2", output_dir="../outputs/analysis", load_best=True):
    os.makedirs(output_dir, exist_ok=True)
    
    checkpoint_paths = sorted(glob.glob(os.path.join(checkpoint_dir, "epoch_*.pt")))
    all_epoch_losses = []
    epoch_numbers = []
    best_ckpt_path = None
    best_loss = float("inf")

    print("\n📋 Epoch-wise Loss Summary:")
    for ckpt_path in checkpoint_paths:
        try:
            checkpoint = torch.load(ckpt_path, map_location="cpu")
            losses = checkpoint.get("epoch_losses", [])
            epoch = checkpoint.get("epoch", None)

            if epoch is not None and losses:
                epoch_numbers.append(epoch)
                last_loss = losses[-1]
                all_epoch_losses.append(last_loss)

                if last_loss < best_loss:
                    best_loss = last_loss
                    best_ckpt_path = ckpt_path

                print(f"Epoch {epoch:02d} → Loss: {last_loss:.7f}")

        except Exception as e:
            print(f"⚠️ Skipped {ckpt_path}: {e}")
    
    # Save loss log
    loss_log_path = os.path.join(output_dir, "compiled_epoch_losses.json")
    with open(loss_log_path, "w") as f:
        json.dump({
            "epoch_numbers": epoch_numbers,
            "epoch_losses": all_epoch_losses
        }, f)
    print(f"\n📄 Saved compiled loss log to: {loss_log_path}")

    # Plot loss curve
    plt.figure(figsize=(8, 5))
    sns.lineplot(x=epoch_numbers, y=all_epoch_losses, marker="o")
    plt.title("📉 Training Loss Curve from Checkpoints")
    plt.xlabel("Epoch")
    plt.ylabel("SmoothL1 Loss")
    plt.grid(True)
    plt.tight_layout()
    plt.savefig(os.path.join(output_dir, "loss_curve_from_ckpts.png"))
    plt.show()

    # Plot deltas
    loss_deltas = [all_epoch_losses[i] - all_epoch_losses[i-1] for i in range(1, len(all_epoch_losses))]
    plt.figure(figsize=(8, 5))
    sns.barplot(x=epoch_numbers[1:], y=loss_deltas)
    plt.title("📊 Δ Loss Between Checkpoints")
    plt.xlabel("Epoch")
    plt.ylabel("Δ Loss")
    plt.grid(True)
    plt.tight_layout()
    plt.savefig(os.path.join(output_dir, "loss_deltas_from_ckpts.png"))
    plt.show()

    print(f"✅ Done analyzing {len(epoch_numbers)} checkpoints")

    # Optional: Load best checkpoint into existing model
    if load_best and best_ckpt_path and model is not None:
        print(f"\n🏆 Loading best checkpoint: {best_ckpt_path} (loss = {best_loss:.7f})")
        device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        checkpoint = torch.load(best_ckpt_path, map_location=device)
        model.load_state_dict(checkpoint['model'])
        model.eval()
        print("📦 Model updated with best checkpoint and set to eval mode.")

    return model

# %%
# Start training
model, loss_log = train_model(
    resume=False,
    num_epochs=70,
    max_cars=5000,
    checkpoint_dir="../outputs/checkpoints2",
    early_stopping_patience=5
)
# Out:
# Epoch 1:   0%|          | 11/2500 [04:55<18:33:26, 26.84s/batch, loss=0.00464]
# ⛔ Interrupted by user. Saving last checkpoint...
# 🧷 Last checkpoint saved. Safe to resume later.

# %%
warnings.filterwarnings("ignore")
# Analyze checkpoints and update model with best weights
model = analyze_all_checkpoints(model=model)
# Out:
# 📋 Epoch-wise Loss Summary:
# Epoch 01 → Loss: 0.0006879
# Epoch 02 → Loss: 0.0002314
# Epoch 03 → Loss: 0.0002070
# Epoch 04 → Loss: 0.0001874
# Epoch 05 → Loss: 0.0001652
# Epoch 06 → Loss: 0.0001606
# Epoch 07 → Loss: 0.0001380
# Epoch 08 → Loss: 0.0001385
# Epoch 09 → Loss: 0.0001377
# Epoch 10 → Loss: 0.0001323
# Epoch 11 → Loss: 0.0001273
# Epoch 12 → Loss: 0.0001197
# Epoch 13 → Loss: 0.0001127
# Epoch 14 → Loss: 0.0001229
# Epoch 15 → Loss: 0.0001115
# Epoch 16 → Loss: 0.0001087
# Epoch 17 → Loss: 0.0001046
# Epoch 18 → Loss: 0.0001022
# Epoch 19 → Loss: 0.0001093
# Epoch 20 → Loss: 0.0001037
# Epoch 21 → Loss: 0.0001144
# Epoch 22 → Loss: 0.0001001
# Epoch 23 → Loss: 0.0000978
# Epoch 24 → Loss: 0.0001008
# Epoch 25 → Loss: 0.0000956
# Epoch 26 → Loss: 0.0000913
# Epoch 27 → Loss: 0.0000971
# Epoch 28 → Loss: 0.0000893
# Epoch 29 → Loss: 0.0000904
# Epoch 30 → Loss: 0.0000893
# Epoch 31 → Loss: 0.0000825
# Epoch 32 → Loss: 0.0000849
# Epoch 33 → Loss: 0.0000842
# Epoch 34 → Loss: 0.0000833
# Epoch 35 → Loss: 0.0000810
# Epoch 36 → Loss: 0.0000851
# Epoch 37 → Loss: 0.0000762
# Epoch 38 → Loss: 0.0000814
# Epoch 39 → Loss: 0.0000790
# Epoch 40 → Loss: 0.0000741
# Epoch 41 → Loss: 0.0000809
# Epoch 42 → Loss: 0.0000751
# Epoch 43 → Loss: 0.0000858
# Epoch 44 → Loss: 0.0000741
# Epoch 45 → Loss: 0.0000791
# Epoch 46 → Loss: 0.0000749
# Epoch 47 → Loss: 0.0000773
# Epoch 48 → Loss: 0.0000743
# Epoch 49 → Loss: 0.0000781
# Epoch 50 → Loss: 0.0000700
# Epoch 51 → Loss: 0.0000712
# Epoch 52 → Loss: 0.0000699
# Epoch 53 → Loss: 0.0000721
# Epoch 54 → Loss: 0.0000692
# Epoch 55 → Loss: 0.0000701
# Epoch 56 → Loss: 0.0000704
# Epoch 57 → Loss: 0.0000694
# Epoch 58 → Loss: 0.0000874
# Epoch 59 → Loss: 0.0000852
#
# 📄 Saved compiled loss log to: ../outputs/analysis\compiled_epoch_losses.json
# ✅ Done analyzing 59 checkpoints
#
# 🏆 Loading best checkpoint: ../outputs/checkpoints\epoch_54_loss_0.0001.pt (loss = 0.0000692)
# 📦 Model updated with best checkpoint and set to eval mode.

# %%
# import torch
# import numpy as np
# import pandas as pd
# from sklearn.metrics import r2_score

# # Load full car IDs from training split
# with open("../data/subset_dir/train_design_ids.txt") as f:
#     all_ids = [line.strip() for line in f]

# # Select 100 unseen IDs after first 1000 used in training
# test_ids = all_ids[5000:5100]

# # Load CSV for ground truth Cd values
# df = pd.read_csv("../data/DrivAerNetPlusPlus_Drag_8k_cleaned.csv")

# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# model.eval()

# preds = []
# trues = []

# for car_id in test_ids:
#     path = f"../outputs/pad_masked_slices/{car_id}_axis-x.npz"
#     data = np.load(path)

#     slices = torch.tensor(data["slices"], dtype=torch.float32).unsqueeze(0).to(device)
#     point_mask = torch.tensor(data["point_mask"], dtype=torch.float32).unsqueeze(0).to(device)
#     slice_mask = torch.tensor(data["slice_mask"], dtype=torch.float32).unsqueeze(0).to(device)

#     with torch.no_grad():
#         cd_pred = model(slices, point_mask, slice_mask).item()

#     cd_true = df[df["Design"] == car_id]["Average Cd"].values[0]

#     preds.append(cd_pred)
#     trues.append(cd_true)

#     print(f"🚗 {car_id} → Predicted Cd: {cd_pred:.4f} | True Cd: {cd_true:.4f}")

# # Compute and print R²
# r2 = r2_score(trues, preds)
# print(f"\n📊 R² Score on unseen 100-car subset: {r2:.4f}")

# %%
# -----------------------------
# 🔍 Robust Evaluation Script for complete Validation/Test Sets
# -----------------------------
import torch
import numpy as np
import pandas as pd
import os
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# CHANGE THIS to 'val_design_ids.txt' or 'test_design_ids.txt'
id_file = "../data/subset_dir/test_design_ids.txt"

# Load car IDs from val/test set
with open(id_file) as f:
    test_ids = [line.strip() for line in f]

# Ground-truth Cd CSV
df = pd.read_csv("../data/DrivAerNetPlusPlus_Drag_8k_cleaned.csv")

# Model setup
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.eval()

# Storage
preds, trues, ids_used = [], [], []

for car_id in test_ids:
    npz_path = f"../outputs/pad_masked_slices/{car_id}_axis-x.npz"
    if not os.path.exists(npz_path):
        print(f"⚠️ Missing file: {car_id}")
        continue

    data = np.load(npz_path)
    slices = torch.tensor(data["slices"], dtype=torch.float32).unsqueeze(0).to(device)
    point_mask = torch.tensor(data["point_mask"], dtype=torch.float32).unsqueeze(0).to(device)
    slice_mask = torch.tensor(data["slice_mask"], dtype=torch.float32).unsqueeze(0).to(device)

    with torch.no_grad():
        cd_pred = model(slices, point_mask, slice_mask).item()

    cd_true = df[df["Design"] == car_id]["Average Cd"].values[0]

    preds.append(cd_pred)
    trues.append(cd_true)
    ids_used.append(car_id)

    print(f"🚗 {car_id} → Predicted Cd: {cd_pred:.6f} | True Cd: {cd_true:.6f}")

# Final Metrics
r2 = r2_score(trues, preds)
mse = mean_squared_error(trues, preds)
mae = mean_absolute_error(trues, preds)

print("\n📊 Evaluation Summary:")
print(f"🔹 R² Score     : {r2:.4f}")
print(f"🔹 MSE          : {mse:.6f}")
print(f"🔹 MAE          : {mae:.6f}")
print(f"🔹 Cars tested  : {len(preds)} / {len(test_ids)}")

# Save predictions
out_path = f"../outputs/eval/cd_predictions_{os.path.basename(id_file).replace('.txt', '')}.csv"
os.makedirs("../outputs/eval", exist_ok=True)
pd.DataFrame({
    "Design ID": ids_used,
    "Predicted Cd": preds,
    "True Cd": trues
}).to_csv(out_path, index=False)
print(f"💾 Saved predictions to: {out_path}")
# Out:
# 🚗 N_S_WWS_WM_172 → Predicted Cd: 0.243838 | True Cd: 0.244182
# 🚗 E_S_WW_WM_615 → Predicted Cd: 0.265982 | True Cd: 0.254449
# 🚗 N_S_WW_WM_256 → Predicted Cd: 0.260751 | True Cd: 0.256448
# 🚗 E_S_WWC_WM_550 → Predicted Cd: 0.279175 | True Cd: 0.275635
# 🚗 N_S_WWC_WM_444 → Predicted Cd: 0.267331 | True Cd: 0.247372
# 🚗 F_S_WWC_WM_541 → Predicted Cd: 0.258747 | True Cd: 0.235396
# 🚗 E_S_WW_WM_567 → Predicted Cd: 0.268704 | True Cd: 0.276847
# 🚗 N_S_WW_WM_316 → Predicted Cd: 0.235067 | True Cd: 0.239067
# 🚗 N_S_WWC_WM_397 → Predicted Cd: 0.238976 | True Cd: 0.225769
# 🚗 N_S_WWS_WM_276 → Predicted Cd: 0.240151 | True Cd: 0.233900
# 🚗 N_S_WWS_WM_322 → Predicted Cd: 0.264986 | True Cd: 0.262816
# 🚗 N_S_WWS_WM_390 → Predicted Cd: 0.240436 | True Cd: 0.226526
# 🚗 E_S_WW_WM_560 → Predicted Cd: 0.266578 | True Cd: 0.225075
# 🚗 N_S_WWS_WM_235 → Predicted Cd: 0.243519 | True Cd: 0.234987
# 🚗 N_S_WW_WM_456 → Predicted Cd: 0.245379 | True Cd: 0.252474
# 🚗 E_S_WW_WM_250 → Predicted Cd: 0.266624 | True Cd: 0.256787
# 🚗 N_S_WWS_WM_050 → Predicted Cd: 0.266529 | True Cd: 0.284210
# 🚗 N_S_WWS_WM_370 → Predicted Cd: 0.249829 | True Cd: 0.244912
# 🚗 N_S_WWC_WM_160 → Predicted Cd: 0.254867 | True Cd: 0.251322
# 🚗 E_S_WWC_WM_570 → Predicted Cd: 0.265924 | True Cd: 0.245412
# 🚗 F_S_WWC_WM_120 → Predicted Cd: 0.237095 | True Cd: 0.248455
# 🚗 F_S_WWC_WM_262 → Predicted Cd: 0.266029 | True Cd: 0.271978
# 🚗 F_S_WWC_WM_056 → Predicted Cd: 0.241030 | True Cd: 0.266300
# 🚗 N_S_WWS_WM_306 → Predicted Cd: 0.237458 | True Cd: 0.222405
# 🚗 N_S_WW_WM_307 → Predicted Cd: 0.239053 | True Cd: 0.223685
# 🚗 N_S_WWS_WM_017 → Predicted Cd: 0.258874 | True Cd: 0.241471
# 🚗 N_S_WW_WM_465 → Predicted Cd: 0.269242 | True Cd: 0.283179
# 🚗 E_S_WWC_WM_241 → Predicted Cd: 0.267195 | True Cd: 0.249293
# 🚗 E_S_WW_WM_202 → Predicted Cd: 0.256895 | True Cd: 0.252496
# 🚗 N_S_WW_WM_614 → Predicted Cd: 0.261786 | True Cd: 0.252592
# 🚗 F_S_WWS_WM_292 → Predicted Cd: 0.239492 | True Cd: 0.236674
# 🚗 N_S_WW_WM_580 → Predicted Cd: 0.243762 | True Cd: 0.255936
# 🚗 F_S_WWC_WM_678 → Predicted Cd: 0.261038 | True Cd: 0.251303
# 🚗 F_S_WWS_WM_591 → Predicted Cd: 0.235381 | True Cd: 0.229069
# 🚗 N_S_WWS_WM_026 → Predicted Cd: 0.244612 | True Cd: 0.226919
# 🚗 F_S_WWS_WM_316 → Predicted Cd: 0.235941 | True Cd: 0.233595
# 🚗 N_S_WWC_WM_189 → Predicted Cd: 0.263299 | True Cd: 0.262842
# 🚗 N_S_WW_WM_628 → Predicted Cd: 0.247195 | True Cd: 0.262460
# 🚗 E_S_WWC_WM_251 → Predicted Cd: 0.281879 | True Cd: 0.307563
# 🚗 N_S_WWC_WM_095 → Predicted Cd: 0.241623 | True Cd: 0.259099
# 🚗 E_S_WWC_WM_008 → Predicted Cd: 0.239919 | True Cd: 0.242909
# 🚗 N_S_WWC_WM_307 → Predicted Cd: 0.239943 | True Cd: 0.223809
# 🚗 F_S_WWS_WM_585 → Predicted Cd: 0.232032 | True Cd: 0.226051
# 🚗 N_S_WWC_WM_515 → Predicted Cd: 0.260712 | True Cd: 0.221476
# 🚗 N_S_WWS_WM_230 → Predicted Cd: 0.260006 | True Cd: 0.239205
# 🚗 E_S_WWC_WM_287 → Predicted Cd: 0.268864 | True Cd: 0.249827
# 🚗 F_S_WWC_WM_133 → Predicted Cd: 0.258641 | True Cd: 0.274476
# 🚗 E_S_WWC_WM_454 → Predicted Cd: 0.278095 | True Cd: 0.274764
# 🚗 N_S_WW_WM_625 → Predicted Cd: 0.245506 | True Cd: 0.228895
# 🚗 F_S_WWC_WM_657 → Predicted Cd: 0.264980 | True Cd: 0.257285
# 🚗 E_S_WW_WM_062 → Predicted Cd: 0.282706 | True Cd: 0.277765
# 🚗 F_S_WWS_WM_297 → Predicted Cd: 0.238927 | True Cd: 0.256199
# 🚗 F_S_WWS_WM_570 → Predicted Cd: 0.240196 | True Cd: 0.227401
# 🚗 E_S_WW_WM_504 → Predicted Cd: 0.274476 | True Cd: 0.293890
# 🚗 E_S_WWC_WM_240 → Predicted Cd: 0.270947 | True Cd: 0.249612
# 🚗 F_S_WWC_WM_205 → Predicted Cd: 0.237563 | True Cd: 0.221841
# 🚗 E_S_WW_WM_034 → Predicted Cd: 0.262565 | True Cd: 0.268081
# 🚗 F_S_WWS_WM_536 → Predicted Cd: 0.239072 | True Cd: 0.228872
# 🚗 N_S_WW_WM_085 → Predicted Cd: 0.243969 | True Cd: 0.245378
# 🚗 F_S_WWC_WM_325 → Predicted Cd: 0.232960 | True Cd: 0.234387
# 🚗 E_S_WWC_WM_458 → Predicted Cd: 0.280398 | True Cd: 0.275145
# 🚗 E_S_WW_WM_287 → Predicted Cd: 0.266016 | True Cd: 0.265526
# 🚗 F_S_WWS_WM_240 → Predicted Cd: 0.228668 | True Cd: 0.223250
# 🚗 E_S_WW_WM_242 → Predicted Cd: 0.276181 | True Cd: 0.295867
# 🚗 E_S_WWC_WM_694 → Predicted Cd: 0.269563 | True Cd: 0.269856
# 🚗 N_S_WWS_WM_323 → Predicted Cd: 0.237761 | True Cd: 0.231111
# 🚗 N_S_WW_WM_020 → Predicted Cd: 0.246561 | True Cd: 0.248067
# 🚗 E_S_WW_WM_554 → Predicted Cd: 0.288162 | True Cd: 0.283066
# 🚗 E_S_WW_WM_403 → Predicted Cd: 0.276769 | True Cd: 0.266991
# 🚗 F_S_WWC_WM_503 → Predicted Cd: 0.263281 | True Cd: 0.272043
# 🚗 N_S_WW_WM_109 → Predicted Cd: 0.270486 | True Cd: 0.280305
# 🚗 N_S_WWS_WM_166 → Predicted Cd: 0.271606 | True Cd: 0.256672
# 🚗 N_S_WWS_WM_057 → Predicted Cd: 0.259140 | True Cd: 0.239286
# 🚗 N_S_WWS_WM_341 → Predicted Cd: 0.257177 | True Cd: 0.243179
# 🚗 F_S_WWS_WM_588 → Predicted Cd: 0.239346 | True Cd: 0.251188
# 🚗 F_S_WWC_WM_054 → Predicted Cd: 0.235576 | True Cd: 0.227160
# 🚗 F_S_WWC_WM_670 → Predicted Cd: 0.238706 | True Cd: 0.261982
# 🚗 F_S_WWC_WM_196 → Predicted Cd: 0.246561 | True Cd: 0.270520
# 🚗 N_S_WWC_WM_218 → Predicted Cd: 0.272142 | True Cd: 0.296369
# 🚗 E_S_WWC_WM_018 → Predicted Cd: 0.279400 | True Cd: 0.312010
# 🚗 N_S_WW_WM_438 → Predicted Cd: 0.268298 | True Cd: 0.269834
# 🚗 N_S_WWS_WM_428 → Predicted Cd: 0.243387 | True Cd: 0.253604
# 🚗 N_S_WWS_WM_337 → Predicted Cd: 0.243212 | True Cd: 0.237998
# 🚗 E_S_WWC_WM_237 → Predicted Cd: 0.264396 | True Cd: 0.251345
# 🚗 E_S_WW_WM_261 → Predicted Cd: 0.272217 | True Cd: 0.274613
# 🚗 N_S_WW_WM_481 → Predicted Cd: 0.254295 | True Cd: 0.241274
# 🚗 F_S_WWS_WM_446 → Predicted Cd: 0.239370 | True Cd: 0.243595
# 🚗 N_S_WWC_WM_278 → Predicted Cd: 0.263774 | True Cd: 0.277911
# 🚗 N_S_WWS_WM_009 → Predicted Cd: 0.248816 | True Cd: 0.255437
# 🚗 E_S_WWC_WM_696 → Predicted Cd: 0.266664 | True Cd: 0.264464
# 🚗 F_S_WWC_WM_186 → Predicted Cd: 0.277383 | True Cd: 0.258471
# 🚗 F_S_WWS_WM_496 → Predicted Cd: 0.232753 | True Cd: 0.235960
# 🚗 F_S_WWC_WM_089 → Predicted Cd: 0.232814 | True Cd: 0.213985
# 🚗 F_S_WWC_WM_328 → Predicted Cd: 0.245715 | True Cd: 0.266373
# 🚗 N_S_WWC_WM_281 → Predicted Cd: 0.265863 | True Cd: 0.269131
# 🚗 E_S_WWC_WM_121 → Predicted Cd: 0.276830 | True Cd: 0.281629
# 🚗 E_S_WW_WM_436 → Predicted Cd: 0.283077 | True Cd: 0.284683
# 🚗 N_S_WWC_WM_456 → Predicted Cd: 0.257516 | True Cd: 0.266135
# 🚗 F_S_WWC_WM_064 → Predicted Cd: 0.231793 | True Cd: 0.242491
# 🚗 E_S_WWC_WM_145 → Predicted Cd: 0.274482 | True Cd: 0.247102
# 🚗 F_S_WWS_WM_252 → Predicted Cd: 0.239790 | True Cd: 0.218377
# 🚗 E_S_WWC_WM_397 → Predicted Cd: 0.284869 | True Cd: 0.290024
# 🚗 E_S_WW_WM_226 → Predicted Cd: 0.255241 | True Cd: 0.257213
# 🚗 N_S_WW_WM_427 → Predicted Cd: 0.247693 | True Cd: 0.232275
# 🚗 N_S_WW_WM_313 → Predicted Cd: 0.249278 | True Cd: 0.254638
# 🚗 N_S_WW_WM_490 → Predicted Cd: 0.245029 | True Cd: 0.249879
# 🚗 N_S_WW_WM_579 → Predicted Cd: 0.260938 | True Cd: 0.265056
# 🚗 E_S_WWC_WM_477 → Predicted Cd: 0.271831 | True Cd: 0.250101
# 🚗 F_S_WWC_WM_598 → Predicted Cd: 0.234309 | True Cd: 0.278951
# 🚗 E_S_WW_WM_613 → Predicted Cd: 0.271406 | True Cd: 0.256642
# 🚗 F_S_WWC_WM_700 → Predicted Cd: 0.271316 | True Cd: 0.296289
# 🚗 E_S_WWC_WM_569 → Predicted Cd: 0.267558 | True Cd: 0.260820
# 🚗 F_S_WWS_WM_234 → Predicted Cd: 0.242032 | True Cd: 0.225451
# 🚗 N_S_WWC_WM_078 → Predicted Cd: 0.262808 | True Cd: 0.264979
# 🚗 E_S_WW_WM_043 → Predicted Cd: 0.280219 | True Cd: 0.275427
# 🚗 F_S_WWS_WM_514 → Predicted Cd: 0.234886 | True Cd: 0.230600
# 🚗 E_S_WWC_WM_265 → Predicted Cd: 0.268156 | True Cd: 0.280255
# 🚗 E_S_WWC_WM_487 → Predicted Cd: 0.268913 | True Cd: 0.248023
# 🚗 N_S_WWS_WM_458 → Predicted Cd: 0.240978 | True Cd: 0.226168
# 🚗 F_S_WWC_WM_397 → Predicted Cd: 0.235517 | True Cd: 0.221561
# 🚗 E_S_WW_WM_289 → Predicted Cd: 0.276400 | True Cd: 0.283370
# 🚗 E_S_WW_WM_488 → Predicted Cd: 0.266934 | True Cd: 0.249099
# 🚗 F_S_WWC_WM_386 → Predicted Cd: 0.231844 | True Cd: 0.211255
# 🚗 N_S_WW_WM_269 → Predicted Cd: 0.260916 | True Cd: 0.236079
# 🚗 N_S_WW_WM_633 → Predicted Cd: 0.267657 | True Cd: 0.256612
# 🚗 F_S_WWS_WM_463 → Predicted Cd: 0.244052 | True Cd: 0.250280
# 🚗 E_S_WWC_WM_219 → Predicted Cd: 0.291433 | True Cd: 0.297134
# 🚗 N_S_WW_WM_416 → Predicted Cd: 0.240636 | True Cd: 0.267815
# 🚗 F_S_WWS_WM_166 → Predicted Cd: 0.267675 | True Cd: 0.259675
# 🚗 F_S_WWC_WM_277 → Predicted Cd: 0.235228 | True Cd: 0.206302
# 🚗 F_S_WWC_WM_637 → Predicted Cd: 0.239247 | True Cd: 0.256673
# 🚗 E_S_WWC_WM_318 → Predicted Cd: 0.279909 | True Cd: 0.286876
# 🚗 E_S_WWC_WM_382 → Predicted Cd: 0.247374 | True Cd: 0.253997
# 🚗 E_S_WWC_WM_245 → Predicted Cd: 0.287157 | True Cd: 0.296983
# 🚗 F_S_WWC_WM_586 → Predicted Cd: 0.236548 | True Cd: 0.246174
# 🚗 F_S_WWS_WM_051 → Predicted Cd: 0.236529 | True Cd: 0.231668
# 🚗 E_S_WWC_WM_350 → Predicted Cd: 0.264633 | True Cd: 0.241381
# 🚗 F_S_WWS_WM_440 → Predicted Cd: 0.260555 | True Cd: 0.250502
# 🚗 E_S_WWC_WM_445 → Predicted Cd: 0.276872 | True Cd: 0.281376
# 🚗 F_S_WWC_WM_087 → Predicted Cd: 0.244592 | True Cd: 0.252027
# 🚗 E_S_WW_WM_399 → Predicted Cd: 0.279331 | True Cd: 0.263480
# 🚗 N_S_WWC_WM_415 → Predicted Cd: 0.245052 | True Cd: 0.238282
# 🚗 F_S_WWC_WM_612 → Predicted Cd: 0.232440 | True Cd: 0.208961
# 🚗 E_S_WWC_WM_399 → Predicted Cd: 0.276463 | True Cd: 0.288820
# 🚗 E_S_WWC_WM_081 → Predicted Cd: 0.276237 | True Cd: 0.262102
# 🚗 E_S_WWC_WM_291 → Predicted Cd: 0.289742 | True Cd: 0.292241
# 🚗 F_S_WWS_WM_466 → Predicted Cd: 0.236950 | True Cd: 0.247560
# 🚗 F_S_WWC_WM_699 → Predicted Cd: 0.269212 | True Cd: 0.278809
# 🚗 E_S_WWC_WM_408 → Predicted Cd: 0.264538 | True Cd: 0.274145
# 🚗 N_S_WWS_WM_407 → Predicted Cd: 0.236698 | True Cd: 0.209269
# 🚗 F_S_WWC_WM_472 → Predicted Cd: 0.258911 | True Cd: 0.269279
# 🚗 N_S_WW_WM_590 → Predicted Cd: 0.242778 | True Cd: 0.266537
# 🚗 E_S_WW_WM_497 → Predicted Cd: 0.268864 | True Cd: 0.238165
# 🚗 E_S_WWC_WM_444 → Predicted Cd: 0.270082 | True Cd: 0.278223
# 🚗 N_S_WW_WM_404 → Predicted Cd: 0.261306 | True Cd: 0.237962
# 🚗 F_S_WWC_WM_141 → Predicted Cd: 0.232808 | True Cd: 0.239258
# 🚗 F_S_WWC_WM_393 → Predicted Cd: 0.241691 | True Cd: 0.234482
# 🚗 F_S_WWS_WM_409 → Predicted Cd: 0.261864 | True Cd: 0.270656
# 🚗 E_S_WWC_WM_295 → Predicted Cd: 0.271346 | True Cd: 0.276116
# 🚗 E_S_WWC_WM_153 → Predicted Cd: 0.259858 | True Cd: 0.288552
# 🚗 E_S_WW_WM_494 → Predicted Cd: 0.275922 | True Cd: 0.289692
# 🚗 F_S_WWS_WM_323 → Predicted Cd: 0.233642 | True Cd: 0.236039
# 🚗 E_S_WWC_WM_074 → Predicted Cd: 0.284975 | True Cd: 0.292229
# 🚗 N_S_WWS_WM_331 → Predicted Cd: 0.269475 | True Cd: 0.263788
# 🚗 E_S_WW_WM_129 → Predicted Cd: 0.262120 | True Cd: 0.256716
# 🚗 E_S_WWC_WM_610 → Predicted Cd: 0.265713 | True Cd: 0.267698
# 🚗 F_S_WWS_WM_303 → Predicted Cd: 0.261456 | True Cd: 0.260300
# 🚗 E_S_WW_WM_637 → Predicted Cd: 0.265386 | True Cd: 0.266738
# 🚗 E_S_WWC_WM_695 → Predicted Cd: 0.267955 | True Cd: 0.268472
# 🚗 E_S_WWC_WM_402 → Predicted Cd: 0.275679 | True Cd: 0.298923
# 🚗 N_S_WWS_WM_430 → Predicted Cd: 0.257965 | True Cd: 0.245752
# 🚗 F_S_WWS_WM_501 → Predicted Cd: 0.239884 | True Cd: 0.225636
# 🚗 E_S_WW_WM_673 → Predicted Cd: 0.267687 | True Cd: 0.268493
# 🚗 N_S_WWC_WM_514 → Predicted Cd: 0.237246 | True Cd: 0.219767
# 🚗 F_S_WWS_WM_650 → Predicted Cd: 0.277816 | True Cd: 0.266460
# 🚗 N_S_WWC_WM_300 → Predicted Cd: 0.239143 | True Cd: 0.215101
# 🚗 E_S_WW_WM_219 → Predicted Cd: 0.290908 | True Cd: 0.294706
# 🚗 F_S_WWS_WM_391 → Predicted Cd: 0.276987 | True Cd: 0.282874
# 🚗 N_S_WW_WM_626 → Predicted Cd: 0.267172 | True Cd: 0.271535
# 🚗 E_S_WWC_WM_218 → Predicted Cd: 0.266480 | True Cd: 0.264403
# 🚗 E_S_WWC_WM_606 → Predicted Cd: 0.276985 | True Cd: 0.267703
# 🚗 N_S_WWS_WM_303 → Predicted Cd: 0.246075 | True Cd: 0.261230
# 🚗 E_S_WWC_WM_364 → Predicted Cd: 0.279915 | True Cd: 0.301900
# 🚗 E_S_WWC_WM_059 → Predicted Cd: 0.287646 | True Cd: 0.294419
# 🚗 N_S_WWC_WM_433 → Predicted Cd: 0.262459 | True Cd: 0.236399
# 🚗 E_S_WW_WM_358 → Predicted Cd: 0.281550 | True Cd: 0.287124
# 🚗 E_S_WW_WM_367 → Predicted Cd: 0.285363 | True Cd: 0.297774
# 🚗 N_S_WW_WM_406 → Predicted Cd: 0.263081 | True Cd: 0.243151
# 🚗 N_S_WW_WM_601 → Predicted Cd: 0.238673 | True Cd: 0.242195
# 🚗 F_S_WWS_WM_401 → Predicted Cd: 0.266381 | True Cd: 0.273819
# 🚗 N_S_WWS_WM_222 → Predicted Cd: 0.252633 | True Cd: 0.257969
# 🚗 E_S_WW_WM_308 → Predicted Cd: 0.270826 | True Cd: 0.295264
# 🚗 F_S_WWS_WM_251 → Predicted Cd: 0.241674 | True Cd: 0.262085
# 🚗 N_S_WW_WM_584 → Predicted Cd: 0.244802 | True Cd: 0.243657
# 🚗 E_S_WWC_WM_068 → Predicted Cd: 0.268758 | True Cd: 0.258078
# 🚗 F_S_WWC_WM_057 → Predicted Cd: 0.238919 | True Cd: 0.248710
# 🚗 E_S_WWC_WM_502 → Predicted Cd: 0.273210 | True Cd: 0.285797
# 🚗 F_S_WWS_WM_230 → Predicted Cd: 0.250928 | True Cd: 0.242325
# 🚗 E_S_WW_WM_268 → Predicted Cd: 0.261560 | True Cd: 0.250968
# 🚗 N_S_WWS_WM_285 → Predicted Cd: 0.240245 | True Cd: 0.231733
# 🚗 N_S_WWC_WM_034 → Predicted Cd: 0.239880 | True Cd: 0.226925
# 🚗 F_S_WWC_WM_504 → Predicted Cd: 0.241268 | True Cd: 0.252944
# 🚗 F_S_WWC_WM_481 → Predicted Cd: 0.239318 | True Cd: 0.242994
# 🚗 N_S_WWC_WM_141 → Predicted Cd: 0.243342 | True Cd: 0.234012
# 🚗 E_S_WWC_WM_539 → Predicted Cd: 0.273837 | True Cd: 0.280206
# 🚗 F_S_WWS_WM_352 → Predicted Cd: 0.268749 | True Cd: 0.258814
# 🚗 F_S_WWS_WM_451 → Predicted Cd: 0.231914 | True Cd: 0.222601
# 🚗 F_S_WWS_WM_384 → Predicted Cd: 0.244894 | True Cd: 0.253071
# 🚗 E_S_WW_WM_389 → Predicted Cd: 0.267432 | True Cd: 0.280026
# 🚗 F_S_WWS_WM_214 → Predicted Cd: 0.246711 | True Cd: 0.245688
# 🚗 E_S_WW_WM_548 → Predicted Cd: 0.275219 | True Cd: 0.295495
# 🚗 F_S_WWC_WM_033 → Predicted Cd: 0.237452 | True Cd: 0.227021
# 🚗 E_S_WWC_WM_044 → Predicted Cd: 0.275560 | True Cd: 0.291999
# 🚗 N_S_WWC_WM_015 → Predicted Cd: 0.249867 | True Cd: 0.246851
# 🚗 N_S_WWC_WM_261 → Predicted Cd: 0.255163 | True Cd: 0.250403
# 🚗 N_S_WW_WM_203 → Predicted Cd: 0.264798 | True Cd: 0.274261
# 🚗 N_S_WW_WM_589 → Predicted Cd: 0.241737 | True Cd: 0.248578
# 🚗 F_S_WWC_WM_030 → Predicted Cd: 0.235788 | True Cd: 0.248866
# 🚗 F_S_WWC_WM_335 → Predicted Cd: 0.267240 | True Cd: 0.277281
# 🚗 E_S_WWC_WM_192 → Predicted Cd: 0.270358 | True Cd: 0.272542
# 🚗 N_S_WWS_WM_403 → Predicted Cd: 0.246202 | True Cd: 0.237223
# 🚗 N_S_WWC_WM_399 → Predicted Cd: 0.245985 | True Cd: 0.244281
# 🚗 N_S_WW_WM_263 → Predicted Cd: 0.240160 | True Cd: 0.208930
# 🚗 N_S_WWS_WM_147 → Predicted Cd: 0.240693 | True Cd: 0.222236
# 🚗 N_S_WW_WM_636 → Predicted Cd: 0.248221 | True Cd: 0.261686
# 🚗 N_S_WW_WM_563 → Predicted Cd: 0.266638 | True Cd: 0.252784
# 🚗 N_S_WWS_WM_234 → Predicted Cd: 0.253874 | True Cd: 0.232224
# 🚗 N_S_WWS_WM_116 → Predicted Cd: 0.272842 | True Cd: 0.276595
# 🚗 N_S_WWS_WM_117 → Predicted Cd: 0.237641 | True Cd: 0.217022
# 🚗 E_S_WW_WM_632 → Predicted Cd: 0.271093 | True Cd: 0.285162
# 🚗 E_S_WW_WM_519 → Predicted Cd: 0.277790 | True Cd: 0.280249
# 🚗 E_S_WWC_WM_256 → Predicted Cd: 0.274876 | True Cd: 0.287371
# 🚗 N_S_WW_WM_454 → Predicted Cd: 0.261505 | True Cd: 0.270957
# 🚗 F_S_WWS_WM_238 → Predicted Cd: 0.242836 | True Cd: 0.229622
# 🚗 E_S_WW_WM_081 → Predicted Cd: 0.265733 | True Cd: 0.251831
# 🚗 F_S_WWS_WM_259 → Predicted Cd: 0.231733 | True Cd: 0.230217
# 🚗 F_S_WWC_WM_147 → Predicted Cd: 0.232350 | True Cd: 0.222973
# 🚗 F_S_WWC_WM_079 → Predicted Cd: 0.258311 | True Cd: 0.234920
# 🚗 F_S_WWS_WM_276 → Predicted Cd: 0.242469 | True Cd: 0.241383
# 🚗 F_S_WWS_WM_231 → Predicted Cd: 0.246029 | True Cd: 0.246758
# 🚗 E_S_WWC_WM_060 → Predicted Cd: 0.274063 | True Cd: 0.269315
# 🚗 N_S_WW_WM_433 → Predicted Cd: 0.262752 | True Cd: 0.244147
# 🚗 E_S_WW_WM_448 → Predicted Cd: 0.270470 | True Cd: 0.279537
# 🚗 E_S_WWC_WM_446 → Predicted Cd: 0.270056 | True Cd: 0.287732
# 🚗 N_S_WWC_WM_132 → Predicted Cd: 0.240214 | True Cd: 0.265392
# 🚗 F_S_WWC_WM_661 → Predicted Cd: 0.265496 | True Cd: 0.254368
# 🚗 E_S_WWC_WM_503 → Predicted Cd: 0.282182 | True Cd: 0.275568
# 🚗 E_S_WWC_WM_013 → Predicted Cd: 0.253477 | True Cd: 0.265013
# 🚗 N_S_WWC_WM_407 → Predicted Cd: 0.232781 | True Cd: 0.204039
# 🚗 E_S_WWC_WM_439 → Predicted Cd: 0.271129 | True Cd: 0.261705
# 🚗 E_S_WWC_WM_189 → Predicted Cd: 0.281222 | True Cd: 0.295961
# 🚗 E_S_WWC_WM_094 → Predicted Cd: 0.270422 | True Cd: 0.258744
# 🚗 F_S_WWS_WM_548 → Predicted Cd: 0.242515 | True Cd: 0.228737
# 🚗 E_S_WW_WM_013 → Predicted Cd: 0.265700 | True Cd: 0.265003
# 🚗 E_S_WWC_WM_070 → Predicted Cd: 0.262908 | True Cd: 0.269889
# 🚗 E_S_WWC_WM_584 → Predicted Cd: 0.264373 | True Cd: 0.266566
# 🚗 E_S_WWC_WM_045 → Predicted Cd: 0.278023 | True Cd: 0.304280
# 🚗 F_S_WWC_WM_185 → Predicted Cd: 0.261569 | True Cd: 0.270820
# 🚗 N_S_WW_WM_025 → Predicted Cd: 0.263765 | True Cd: 0.250240
# 🚗 F_S_WWC_WM_037 → Predicted Cd: 0.240583 | True Cd: 0.235629
# 🚗 N_S_WWS_WM_391 → Predicted Cd: 0.266776 | True Cd: 0.273742
# 🚗 N_S_WWC_WM_104 → Predicted Cd: 0.243638 | True Cd: 0.242213
# 🚗 E_S_WW_WM_526 → Predicted Cd: 0.269927 | True Cd: 0.256919
# 🚗 E_S_WWC_WM_633 → Predicted Cd: 0.278310 | True Cd: 0.289202
# 🚗 F_S_WWS_WM_162 → Predicted Cd: 0.232068 | True Cd: 0.212927
# 🚗 N_S_WWS_WM_175 → Predicted Cd: 0.238048 | True Cd: 0.246576
# 🚗 E_S_WWC_WM_032 → Predicted Cd: 0.277943 | True Cd: 0.293619
# 🚗 E_S_WW_WM_212 → Predicted Cd: 0.278448 | True Cd: 0.288329
# 🚗 E_S_WWC_WM_698 → Predicted Cd: 0.265942 | True Cd: 0.247173
# 🚗 N_S_WWS_WM_002 → Predicted Cd: 0.240160 | True Cd: 0.225229
# 🚗 E_S_WWC_WM_208 → Predicted Cd: 0.238465 | True Cd: 0.255264
# 🚗 E_S_WW_WM_518 → Predicted Cd: 0.275983 | True Cd: 0.278139
# 🚗 E_S_WWC_WM_252 → Predicted Cd: 0.260589 | True Cd: 0.261120
# 🚗 F_S_WWC_WM_373 → Predicted Cd: 0.234573 | True Cd: 0.236819
# 🚗 E_S_WW_WM_634 → Predicted Cd: 0.266478 | True Cd: 0.286090
# 🚗 E_S_WW_WM_646 → Predicted Cd: 0.272139 | True Cd: 0.273345
# 🚗 F_S_WWS_WM_375 → Predicted Cd: 0.281256 | True Cd: 0.305915
# 🚗 E_S_WW_WM_119 → Predicted Cd: 0.273849 | True Cd: 0.272798
# 🚗 N_S_WWC_WM_019 → Predicted Cd: 0.277460 | True Cd: 0.265278
# 🚗 E_S_WW_WM_470 → Predicted Cd: 0.280179 | True Cd: 0.284398
# 🚗 E_S_WWC_WM_015 → Predicted Cd: 0.277293 | True Cd: 0.274021
# 🚗 E_S_WW_WM_586 → Predicted Cd: 0.277253 | True Cd: 0.289784
# 🚗 N_S_WWS_WM_189 → Predicted Cd: 0.261371 | True Cd: 0.241766
# 🚗 N_S_WWC_WM_127 → Predicted Cd: 0.235213 | True Cd: 0.212061
# 🚗 F_S_WWS_WM_535 → Predicted Cd: 0.236777 | True Cd: 0.231648
# 🚗 E_S_WWC_WM_062 → Predicted Cd: 0.285519 | True Cd: 0.281116
# 🚗 N_S_WW_WM_268 → Predicted Cd: 0.243681 | True Cd: 0.240742
# 🚗 E_S_WW_WM_684 → Predicted Cd: 0.265393 | True Cd: 0.245519
# 🚗 E_S_WWC_WM_442 → Predicted Cd: 0.266666 | True Cd: 0.252455
# 🚗 F_S_WWC_WM_105 → Predicted Cd: 0.264682 | True Cd: 0.265349
# 🚗 N_S_WW_WM_559 → Predicted Cd: 0.241863 | True Cd: 0.237129
# 🚗 F_S_WWC_WM_083 → Predicted Cd: 0.255982 | True Cd: 0.270096
# 🚗 F_S_WWC_WM_150 → Predicted Cd: 0.248109 | True Cd: 0.244257
# 🚗 F_S_WWC_WM_012 → Predicted Cd: 0.242162 | True Cd: 0.242184
# 🚗 N_S_WWC_WM_203 → Predicted Cd: 0.264657 | True Cd: 0.280960
# 🚗 F_S_WWC_WM_307 → Predicted Cd: 0.241793 | True Cd: 0.232554
# 🚗 E_S_WWC_WM_033 → Predicted Cd: 0.283246 | True Cd: 0.287701
# 🚗 N_S_WW_WM_303 → Predicted Cd: 0.252033 | True Cd: 0.257726
# 🚗 E_S_WW_WM_186 → Predicted Cd: 0.281677 | True Cd: 0.283453
# 🚗 F_S_WWC_WM_197 → Predicted Cd: 0.255746 | True Cd: 0.255567
# 🚗 E_S_WWC_WM_365 → Predicted Cd: 0.278186 | True Cd: 0.279035
# 🚗 F_S_WWC_WM_569 → Predicted Cd: 0.244115 | True Cd: 0.243195
# 🚗 F_S_WWC_WM_427 → Predicted Cd: 0.241215 | True Cd: 0.247580
# 🚗 E_S_WWC_WM_262 → Predicted Cd: 0.273421 | True Cd: 0.275416
# 🚗 E_S_WW_WM_408 → Predicted Cd: 0.273164 | True Cd: 0.287625
# 🚗 N_S_WWS_WM_159 → Predicted Cd: 0.240871 | True Cd: 0.245172
# 🚗 N_S_WWS_WM_399 → Predicted Cd: 0.244157 | True Cd: 0.240317
# 🚗 E_S_WWC_WM_366 → Predicted Cd: 0.269825 | True Cd: 0.280267
# 🚗 N_S_WWC_WM_473 → Predicted Cd: 0.242538 | True Cd: 0.229555
# 🚗 N_S_WWC_WM_135 → Predicted Cd: 0.245353 | True Cd: 0.250160
# 🚗 N_S_WWS_WM_256 → Predicted Cd: 0.264046 | True Cd: 0.231850
# 🚗 F_S_WWS_WM_632 → Predicted Cd: 0.239266 | True Cd: 0.245936
# 🚗 F_S_WWS_WM_271 → Predicted Cd: 0.266207 | True Cd: 0.270776
# 🚗 F_S_WWS_WM_427 → Predicted Cd: 0.240540 | True Cd: 0.224477
# 🚗 N_S_WW_WM_096 → Predicted Cd: 0.235524 | True Cd: 0.211462
# 🚗 N_S_WW_WM_471 → Predicted Cd: 0.244796 | True Cd: 0.247435
# 🚗 N_S_WWS_WM_112 → Predicted Cd: 0.266114 | True Cd: 0.263813
# 🚗 E_S_WWC_WM_030 → Predicted Cd: 0.259973 | True Cd: 0.260890
# 🚗 E_S_WW_WM_111 → Predicted Cd: 0.247374 | True Cd: 0.249132
# 🚗 E_S_WWC_WM_690 → Predicted Cd: 0.270460 | True Cd: 0.281988
# 🚗 E_S_WW_WM_445 → Predicted Cd: 0.272621 | True Cd: 0.283104
# 🚗 E_S_WW_WM_155 → Predicted Cd: 0.280708 | True Cd: 0.297244
# 🚗 N_S_WWS_WM_340 → Predicted Cd: 0.235657 | True Cd: 0.227117
# 🚗 E_S_WWC_WM_526 → Predicted Cd: 0.272161 | True Cd: 0.262588
# 🚗 N_S_WWC_WM_244 → Predicted Cd: 0.265449 | True Cd: 0.265409
# 🚗 E_S_WWC_WM_552 → Predicted Cd: 0.272335 | True Cd: 0.285576
# 🚗 N_S_WWC_WM_058 → Predicted Cd: 0.243675 | True Cd: 0.243199
# 🚗 F_S_WWC_WM_290 → Predicted Cd: 0.241909 | True Cd: 0.258092
# 🚗 N_S_WWS_WM_029 → Predicted Cd: 0.249122 | True Cd: 0.233732
# 🚗 N_S_WW_WM_243 → Predicted Cd: 0.242802 | True Cd: 0.228595
# 🚗 E_S_WW_WM_683 → Predicted Cd: 0.266730 | True Cd: 0.281550
# 🚗 N_S_WWC_WM_035 → Predicted Cd: 0.260844 | True Cd: 0.268252
# 🚗 F_S_WWC_WM_227 → Predicted Cd: 0.266382 | True Cd: 0.262787
# 🚗 F_S_WWC_WM_223 → Predicted Cd: 0.258927 | True Cd: 0.251437
# 🚗 F_S_WWC_WM_628 → Predicted Cd: 0.245975 | True Cd: 0.262535
# 🚗 E_S_WWC_WM_415 → Predicted Cd: 0.275567 | True Cd: 0.279307
# 🚗 E_S_WW_WM_475 → Predicted Cd: 0.264070 | True Cd: 0.263107
# 🚗 F_S_WWS_WM_314 → Predicted Cd: 0.242002 | True Cd: 0.235961
# 🚗 F_S_WWC_WM_450 → Predicted Cd: 0.236861 | True Cd: 0.241308
# 🚗 N_S_WW_WM_100 → Predicted Cd: 0.254346 | True Cd: 0.259882
# 🚗 N_S_WW_WM_473 → Predicted Cd: 0.243259 | True Cd: 0.222013
# 🚗 N_S_WW_WM_662 → Predicted Cd: 0.245105 | True Cd: 0.243321
# 🚗 E_S_WW_WM_678 → Predicted Cd: 0.269226 | True Cd: 0.272970
# 🚗 F_S_WWC_WM_008 → Predicted Cd: 0.232580 | True Cd: 0.229100
# 🚗 E_S_WWC_WM_112 → Predicted Cd: 0.267312 | True Cd: 0.260120
# 🚗 F_S_WWS_WM_320 → Predicted Cd: 0.263167 | True Cd: 0.260745
# 🚗 E_S_WWC_WM_323 → Predicted Cd: 0.261168 | True Cd: 0.258780
# 🚗 F_S_WWC_WM_294 → Predicted Cd: 0.239364 | True Cd: 0.251463
# 🚗 E_S_WWC_WM_281 → Predicted Cd: 0.284194 | True Cd: 0.296592
# 🚗 N_S_WWC_WM_474 → Predicted Cd: 0.245105 | True Cd: 0.243604
# 🚗 F_S_WWC_WM_416 → Predicted Cd: 0.235995 | True Cd: 0.257065
# 🚗 E_S_WWC_WM_376 → Predicted Cd: 0.272266 | True Cd: 0.281259
# 🚗 N_S_WWS_WM_058 → Predicted Cd: 0.244210 | True Cd: 0.250305
# 🚗 E_S_WWC_WM_462 → Predicted Cd: 0.266400 | True Cd: 0.253519
# 🚗 F_S_WWC_WM_146 → Predicted Cd: 0.244437 | True Cd: 0.246192
# 🚗 F_S_WWS_WM_206 → Predicted Cd: 0.236587 | True Cd: 0.238805
# 🚗 F_S_WWS_WM_301 → Predicted Cd: 0.244360 | True Cd: 0.222389
# 🚗 E_S_WWC_WM_421 → Predicted Cd: 0.241624 | True Cd: 0.274526
# 🚗 F_S_WWC_WM_340 → Predicted Cd: 0.235975 | True Cd: 0.216006
# 🚗 E_S_WW_WM_695 → Predicted Cd: 0.258552 | True Cd: 0.243371
# 🚗 F_S_WWS_WM_418 → Predicted Cd: 0.237536 | True Cd: 0.236126
# 🚗 E_S_WWC_WM_505 → Predicted Cd: 0.289623 | True Cd: 0.293659
# 🚗 E_S_WW_WM_467 → Predicted Cd: 0.279817 | True Cd: 0.282371
# 🚗 F_S_WWS_WM_112 → Predicted Cd: 0.243452 | True Cd: 0.246627
# 🚗 N_S_WW_WM_257 → Predicted Cd: 0.241330 | True Cd: 0.222396
# 🚗 E_S_WW_WM_355 → Predicted Cd: 0.250661 | True Cd: 0.245147
# 🚗 N_S_WWC_WM_024 → Predicted Cd: 0.245294 | True Cd: 0.246695
# 🚗 E_S_WW_WM_007 → Predicted Cd: 0.272633 | True Cd: 0.279271
# 🚗 F_S_WWS_WM_172 → Predicted Cd: 0.234201 | True Cd: 0.233822
# 🚗 N_S_WWC_WM_106 → Predicted Cd: 0.241890 | True Cd: 0.243444
# 🚗 F_S_WWC_WM_130 → Predicted Cd: 0.273211 | True Cd: 0.273190
# 🚗 E_S_WW_WM_514 → Predicted Cd: 0.262203 | True Cd: 0.263825
# 🚗 N_S_WWS_WM_114 → Predicted Cd: 0.238657 | True Cd: 0.238307
# 🚗 N_S_WWC_WM_235 → Predicted Cd: 0.244297 | True Cd: 0.230174
# 🚗 N_S_WWS_WM_121 → Predicted Cd: 0.265142 | True Cd: 0.241836
# 🚗 N_S_WWC_WM_005 → Predicted Cd: 0.272211 | True Cd: 0.253499
# 🚗 E_S_WWC_WM_325 → Predicted Cd: 0.281010 | True Cd: 0.271697
# 🚗 F_S_WWC_WM_192 → Predicted Cd: 0.234145 | True Cd: 0.214651
# 🚗 N_S_WWS_WM_043 → Predicted Cd: 0.239273 | True Cd: 0.221514
# 🚗 F_S_WWC_WM_423 → Predicted Cd: 0.239035 | True Cd: 0.227915
# 🚗 F_S_WWS_WM_324 → Predicted Cd: 0.259288 | True Cd: 0.252491
# 🚗 E_S_WW_WM_463 → Predicted Cd: 0.268984 | True Cd: 0.283515
# 🚗 F_S_WWC_WM_627 → Predicted Cd: 0.236819 | True Cd: 0.226383
# 🚗 E_S_WWC_WM_125 → Predicted Cd: 0.257601 | True Cd: 0.254123
# 🚗 F_S_WWS_WM_129 → Predicted Cd: 0.235251 | True Cd: 0.244897
# 🚗 F_S_WWC_WM_651 → Predicted Cd: 0.259522 | True Cd: 0.281078
# 🚗 N_S_WW_WM_281 → Predicted Cd: 0.265407 | True Cd: 0.272454
# 🚗 N_S_WW_WM_046 → Predicted Cd: 0.242966 | True Cd: 0.231154
# 🚗 N_S_WWS_WM_451 → Predicted Cd: 0.232340 | True Cd: 0.231206
# 🚗 N_S_WWC_WM_033 → Predicted Cd: 0.245750 | True Cd: 0.225156
# 🚗 F_S_WWS_WM_176 → Predicted Cd: 0.235247 | True Cd: 0.249118
# 🚗 F_S_WWS_WM_344 → Predicted Cd: 0.246877 | True Cd: 0.242129
# 🚗 E_S_WW_WM_363 → Predicted Cd: 0.275067 | True Cd: 0.281054
# 🚗 E_S_WW_WM_536 → Predicted Cd: 0.259279 | True Cd: 0.237953
# 🚗 F_S_WWC_WM_172 → Predicted Cd: 0.235186 | True Cd: 0.244705
# 🚗 F_S_WWS_WM_117 → Predicted Cd: 0.232811 | True Cd: 0.214949
# 🚗 F_S_WWC_WM_190 → Predicted Cd: 0.236752 | True Cd: 0.242501
# 🚗 E_S_WWC_WM_046 → Predicted Cd: 0.265081 | True Cd: 0.247993
# 🚗 N_S_WW_WM_503 → Predicted Cd: 0.263375 | True Cd: 0.275104
# 🚗 E_S_WWC_WM_329 → Predicted Cd: 0.273321 | True Cd: 0.289793
# 🚗 E_S_WWC_WM_585 → Predicted Cd: 0.268496 | True Cd: 0.251455
# 🚗 E_S_WW_WM_558 → Predicted Cd: 0.287206 | True Cd: 0.311270
# 🚗 F_S_WWS_WM_095 → Predicted Cd: 0.240895 | True Cd: 0.231199
# 🚗 E_S_WWC_WM_053 → Predicted Cd: 0.276085 | True Cd: 0.275417
# 🚗 F_S_WWC_WM_292 → Predicted Cd: 0.240278 | True Cd: 0.254872
# 🚗 F_S_WWS_WM_433 → Predicted Cd: 0.239127 | True Cd: 0.240766
# 🚗 E_S_WWC_WM_406 → Predicted Cd: 0.275167 | True Cd: 0.278714
# 🚗 E_S_WWC_WM_479 → Predicted Cd: 0.279757 | True Cd: 0.301113
# 🚗 N_S_WW_WM_418 → Predicted Cd: 0.233871 | True Cd: 0.246595
# 🚗 E_S_WW_WM_009 → Predicted Cd: 0.272469 | True Cd: 0.279743
# 🚗 F_S_WWS_WM_447 → Predicted Cd: 0.248299 | True Cd: 0.270293
# 🚗 E_S_WWC_WM_516 → Predicted Cd: 0.262986 | True Cd: 0.238727
# 🚗 N_S_WWS_WM_023 → Predicted Cd: 0.254910 | True Cd: 0.227274
# 🚗 F_S_WWC_WM_412 → Predicted Cd: 0.243183 | True Cd: 0.257369
# 🚗 E_S_WW_WM_600 → Predicted Cd: 0.274512 | True Cd: 0.311372
# 🚗 E_S_WWC_WM_677 → Predicted Cd: 0.277593 | True Cd: 0.298804
# 🚗 E_S_WW_WM_331 → Predicted Cd: 0.272625 | True Cd: 0.289376
# 🚗 F_S_WWS_WM_398 → Predicted Cd: 0.239806 | True Cd: 0.235913
# 🚗 F_S_WWS_WM_146 → Predicted Cd: 0.245534 | True Cd: 0.237372
# 🚗 N_S_WW_WM_065 → Predicted Cd: 0.264025 | True Cd: 0.231128
# 🚗 E_S_WWC_WM_150 → Predicted Cd: 0.273872 | True Cd: 0.275016
# 🚗 E_S_WWC_WM_354 → Predicted Cd: 0.275630 | True Cd: 0.278888
# 🚗 E_S_WW_WM_423 → Predicted Cd: 0.282569 | True Cd: 0.287893
# 🚗 F_S_WWS_WM_186 → Predicted Cd: 0.277716 | True Cd: 0.253477
# 🚗 F_S_WWS_WM_294 → Predicted Cd: 0.238620 | True Cd: 0.244136
# 🚗 F_S_WWC_WM_452 → Predicted Cd: 0.241791 | True Cd: 0.257900
# 🚗 F_S_WWC_WM_274 → Predicted Cd: 0.242932 | True Cd: 0.233445
# 🚗 F_S_WWS_WM_526 → Predicted Cd: 0.235243 | True Cd: 0.215168
# 🚗 N_S_WWC_WM_025 → Predicted Cd: 0.264931 | True Cd: 0.278058
# 🚗 F_S_WWS_WM_253 → Predicted Cd: 0.260828 | True Cd: 0.287227
# 🚗 E_S_WWC_WM_158 → Predicted Cd: 0.264366 | True Cd: 0.244230
# 🚗 E_S_WW_WM_338 → Predicted Cd: 0.280082 | True Cd: 0.291421
# 🚗 F_S_WWC_WM_220 → Predicted Cd: 0.244363 | True Cd: 0.236359
# 🚗 N_S_WWC_WM_031 → Predicted Cd: 0.236722 | True Cd: 0.219924
# 🚗 N_S_WW_WM_092 → Predicted Cd: 0.264273 | True Cd: 0.266438
# 🚗 E_S_WWC_WM_358 → Predicted Cd: 0.267445 | True Cd: 0.255692
# 🚗 F_S_WWC_WM_549 → Predicted Cd: 0.272234 | True Cd: 0.283797
# 🚗 E_S_WW_WM_696 → Predicted Cd: 0.280217 | True Cd: 0.286585
# 🚗 N_S_WWC_WM_283 → Predicted Cd: 0.246761 | True Cd: 0.244436
# 🚗 E_S_WW_WM_501 → Predicted Cd: 0.272801 | True Cd: 0.275535
# 🚗 N_S_WW_WM_278 → Predicted Cd: 0.259750 | True Cd: 0.250836
# 🚗 F_S_WWS_WM_489 → Predicted Cd: 0.241391 | True Cd: 0.234215
# 🚗 N_S_WWC_WM_376 → Predicted Cd: 0.259994 | True Cd: 0.254744
# 🚗 F_S_WWS_WM_220 → Predicted Cd: 0.242284 | True Cd: 0.224821
# 🚗 F_S_WWC_WM_560 → Predicted Cd: 0.232668 | True Cd: 0.218256
# 🚗 N_S_WW_WM_221 → Predicted Cd: 0.245254 | True Cd: 0.228851
# 🚗 N_S_WWS_WM_047 → Predicted Cd: 0.240353 | True Cd: 0.220155
# 🚗 E_S_WW_WM_438 → Predicted Cd: 0.275240 | True Cd: 0.290553
# 🚗 E_S_WWC_WM_196 → Predicted Cd: 0.285142 | True Cd: 0.282927
# 🚗 F_S_WWS_WM_053 → Predicted Cd: 0.239205 | True Cd: 0.237399
# 🚗 N_S_WW_WM_478 → Predicted Cd: 0.243763 | True Cd: 0.243139
# 🚗 N_S_WWC_WM_384 → Predicted Cd: 0.257464 | True Cd: 0.251984
# 🚗 F_S_WWC_WM_511 → Predicted Cd: 0.237929 | True Cd: 0.261105
# 🚗 E_S_WWC_WM_001 → Predicted Cd: 0.285959 | True Cd: 0.294129
# 🚗 F_S_WWS_WM_066 → Predicted Cd: 0.232454 | True Cd: 0.223611
# 🚗 E_S_WW_WM_444 → Predicted Cd: 0.273339 | True Cd: 0.266917
# 🚗 N_S_WW_WM_556 → Predicted Cd: 0.233339 | True Cd: 0.225097
# 🚗 E_S_WWC_WM_666 → Predicted Cd: 0.278904 | True Cd: 0.285856
# 🚗 E_S_WW_WM_401 → Predicted Cd: 0.286460 | True Cd: 0.302942
# 🚗 F_S_WWS_WM_621 → Predicted Cd: 0.261450 | True Cd: 0.258438
# 🚗 E_S_WWC_WM_097 → Predicted Cd: 0.276878 | True Cd: 0.282493
# 🚗 N_S_WWS_WM_091 → Predicted Cd: 0.271707 | True Cd: 0.276810
# 🚗 F_S_WWS_WM_081 → Predicted Cd: 0.237125 | True Cd: 0.228970
# 🚗 N_S_WWS_WM_241 → Predicted Cd: 0.235774 | True Cd: 0.221487
# 🚗 N_S_WWS_WM_397 → Predicted Cd: 0.239201 | True Cd: 0.236128
# 🚗 E_S_WW_WM_648 → Predicted Cd: 0.268243 | True Cd: 0.249616
# 🚗 E_S_WWC_WM_136 → Predicted Cd: 0.281338 | True Cd: 0.286293
# 🚗 E_S_WW_WM_164 → Predicted Cd: 0.278671 | True Cd: 0.296914
# 🚗 F_S_WWC_WM_285 → Predicted Cd: 0.233512 | True Cd: 0.214667
# 🚗 N_S_WWC_WM_088 → Predicted Cd: 0.241265 | True Cd: 0.223739
# 🚗 F_S_WWC_WM_310 → Predicted Cd: 0.241383 | True Cd: 0.267478
# 🚗 E_S_WW_WM_072 → Predicted Cd: 0.259116 | True Cd: 0.302202
# 🚗 F_S_WWC_WM_409 → Predicted Cd: 0.259709 | True Cd: 0.262247
# 🚗 F_S_WWS_WM_455 → Predicted Cd: 0.237942 | True Cd: 0.244790
# 🚗 E_S_WW_WM_011 → Predicted Cd: 0.285242 | True Cd: 0.277588
# 🚗 E_S_WW_WM_608 → Predicted Cd: 0.280961 | True Cd: 0.289079
# 🚗 F_S_WWC_WM_585 → Predicted Cd: 0.231752 | True Cd: 0.216839
# 🚗 N_S_WW_WM_001 → Predicted Cd: 0.267277 | True Cd: 0.270224
# 🚗 N_S_WW_WM_300 → Predicted Cd: 0.237447 | True Cd: 0.220224
# 🚗 N_S_WW_WM_136 → Predicted Cd: 0.255228 | True Cd: 0.256464
# 🚗 E_S_WWC_WM_305 → Predicted Cd: 0.269532 | True Cd: 0.279327
# 🚗 E_S_WW_WM_217 → Predicted Cd: 0.266089 | True Cd: 0.264876
# 🚗 F_S_WWC_WM_038 → Predicted Cd: 0.234954 | True Cd: 0.214864
# 🚗 F_S_WWS_WM_665 → Predicted Cd: 0.245318 | True Cd: 0.244714
# 🚗 E_S_WWC_WM_427 → Predicted Cd: 0.275686 | True Cd: 0.269472
# 🚗 F_S_WWS_WM_557 → Predicted Cd: 0.240894 | True Cd: 0.260037
# 🚗 F_S_WWS_WM_002 → Predicted Cd: 0.238520 | True Cd: 0.219522
# 🚗 N_S_WWC_WM_177 → Predicted Cd: 0.265479 | True Cd: 0.281977
# 🚗 E_S_WWC_WM_367 → Predicted Cd: 0.287050 | True Cd: 0.299099
# 🚗 N_S_WWC_WM_455 → Predicted Cd: 0.244912 | True Cd: 0.235922
# 🚗 F_S_WWS_WM_399 → Predicted Cd: 0.242007 | True Cd: 0.233915
# 🚗 E_S_WW_WM_214 → Predicted Cd: 0.267778 | True Cd: 0.261004
# 🚗 N_S_WWC_WM_421 → Predicted Cd: 0.247374 | True Cd: 0.251350
# 🚗 F_S_WWC_WM_442 → Predicted Cd: 0.234351 | True Cd: 0.222273
# 🚗 F_S_WWS_WM_473 → Predicted Cd: 0.242385 | True Cd: 0.217723
# 🚗 F_S_WWC_WM_660 → Predicted Cd: 0.254256 | True Cd: 0.257863
# 🚗 E_S_WWC_WM_248 → Predicted Cd: 0.275973 | True Cd: 0.273513
# 🚗 E_S_WW_WM_104 → Predicted Cd: 0.246167 | True Cd: 0.265022
# 🚗 E_S_WW_WM_156 → Predicted Cd: 0.275838 | True Cd: 0.303216
# 🚗 E_S_WWC_WM_470 → Predicted Cd: 0.278404 | True Cd: 0.283132
# 🚗 E_S_WW_WM_222 → Predicted Cd: 0.273268 | True Cd: 0.285603
# 🚗 N_S_WWS_WM_378 → Predicted Cd: 0.263195 | True Cd: 0.253180
# 🚗 N_S_WW_WM_420 → Predicted Cd: 0.258630 | True Cd: 0.266029
# 🚗 F_S_WWC_WM_364 → Predicted Cd: 0.247975 | True Cd: 0.279335
# 🚗 F_S_WWC_WM_152 → Predicted Cd: 0.239487 | True Cd: 0.229503
# 🚗 E_S_WWC_WM_380 → Predicted Cd: 0.288554 | True Cd: 0.305922
# 🚗 F_S_WWS_WM_509 → Predicted Cd: 0.240596 | True Cd: 0.246758
# 🚗 F_S_WWS_WM_369 → Predicted Cd: 0.239885 | True Cd: 0.239128
# 🚗 E_S_WWC_WM_547 → Predicted Cd: 0.267257 | True Cd: 0.247861
# 🚗 E_S_WWC_WM_341 → Predicted Cd: 0.256921 | True Cd: 0.257512
# 🚗 F_S_WWS_WM_246 → Predicted Cd: 0.253790 | True Cd: 0.258158
# 🚗 E_S_WW_WM_428 → Predicted Cd: 0.266676 | True Cd: 0.273290
# 🚗 F_S_WWC_WM_394 → Predicted Cd: 0.257224 | True Cd: 0.267132
# 🚗 E_S_WWC_WM_564 → Predicted Cd: 0.255768 | True Cd: 0.275804
# 🚗 E_S_WW_WM_021 → Predicted Cd: 0.276045 | True Cd: 0.284251
# 🚗 E_S_WW_WM_517 → Predicted Cd: 0.287236 | True Cd: 0.310219
# 🚗 N_S_WW_WM_066 → Predicted Cd: 0.236614 | True Cd: 0.231790
# 🚗 F_S_WWC_WM_421 → Predicted Cd: 0.242614 | True Cd: 0.243458
# 🚗 E_S_WWC_WM_023 → Predicted Cd: 0.285550 | True Cd: 0.280493
# 🚗 F_S_WWC_WM_368 → Predicted Cd: 0.254319 | True Cd: 0.271235
# 🚗 E_S_WWC_WM_471 → Predicted Cd: 0.266334 | True Cd: 0.282419
# 🚗 E_S_WWC_WM_525 → Predicted Cd: 0.253752 | True Cd: 0.245930
# 🚗 E_S_WW_WM_271 → Predicted Cd: 0.281840 | True Cd: 0.289646
# 🚗 F_S_WWS_WM_429 → Predicted Cd: 0.231849 | True Cd: 0.240243
# 🚗 F_S_WWC_WM_151 → Predicted Cd: 0.256918 | True Cd: 0.228427
# 🚗 F_S_WWS_WM_654 → Predicted Cd: 0.236000 | True Cd: 0.235296
# 🚗 F_S_WWC_WM_253 → Predicted Cd: 0.255938 | True Cd: 0.285927
# 🚗 F_S_WWC_WM_321 → Predicted Cd: 0.242702 | True Cd: 0.237670
# 🚗 F_S_WWS_WM_001 → Predicted Cd: 0.265474 | True Cd: 0.276403
# 🚗 F_S_WWC_WM_606 → Predicted Cd: 0.255451 | True Cd: 0.242527
# 🚗 F_S_WWC_WM_204 → Predicted Cd: 0.246228 | True Cd: 0.238774
# 🚗 E_S_WW_WM_098 → Predicted Cd: 0.276901 | True Cd: 0.275752
# 🚗 F_S_WWS_WM_022 → Predicted Cd: 0.237408 | True Cd: 0.237728
# 🚗 F_S_WWC_WM_656 → Predicted Cd: 0.235181 | True Cd: 0.233007
# 🚗 F_S_WWS_WM_309 → Predicted Cd: 0.244132 | True Cd: 0.251811
# 🚗 N_S_WW_WM_619 → Predicted Cd: 0.261418 | True Cd: 0.246358
# 🚗 N_S_WWC_WM_053 → Predicted Cd: 0.242780 | True Cd: 0.253825
# 🚗 N_S_WWC_WM_459 → Predicted Cd: 0.255005 | True Cd: 0.276726
# 🚗 E_S_WWC_WM_384 → Predicted Cd: 0.279691 | True Cd: 0.298667
# 🚗 E_S_WWC_WM_334 → Predicted Cd: 0.265445 | True Cd: 0.247987
# 🚗 N_S_WWS_WM_482 → Predicted Cd: 0.237621 | True Cd: 0.224615
# 🚗 F_S_WWS_WM_203 → Predicted Cd: 0.264279 | True Cd: 0.273024
# 🚗 E_S_WWC_WM_225 → Predicted Cd: 0.256389 | True Cd: 0.288577
# 🚗 E_S_WWC_WM_511 → Predicted Cd: 0.281415 | True Cd: 0.279148
# 🚗 F_S_WWS_WM_383 → Predicted Cd: 0.255371 | True Cd: 0.270135
# 🚗 E_S_WW_WM_485 → Predicted Cd: 0.259980 | True Cd: 0.275219
# 🚗 E_S_WWC_WM_297 → Predicted Cd: 0.244129 | True Cd: 0.251155
# 🚗 F_S_WWS_WM_481 → Predicted Cd: 0.238742 | True Cd: 0.230859
# 🚗 F_S_WWS_WM_583 → Predicted Cd: 0.263073 | True Cd: 0.264491
# 🚗 E_S_WWC_WM_521 → Predicted Cd: 0.267102 | True Cd: 0.263836
# 🚗 N_S_WWS_WM_089 → Predicted Cd: 0.234511 | True Cd: 0.204963
# 🚗 E_S_WWC_WM_181 → Predicted Cd: 0.283659 | True Cd: 0.295565
# 🚗 N_S_WWS_WM_075 → Predicted Cd: 0.236161 | True Cd: 0.237715
# 🚗 E_S_WW_WM_653 → Predicted Cd: 0.262632 | True Cd: 0.232595
# 🚗 N_S_WWS_WM_410 → Predicted Cd: 0.236954 | True Cd: 0.220727
# 🚗 E_S_WW_WM_193 → Predicted Cd: 0.259337 | True Cd: 0.266098
# 🚗 F_S_WWS_WM_260 → Predicted Cd: 0.245143 | True Cd: 0.230253
# 🚗 F_S_WWS_WM_289 → Predicted Cd: 0.268631 | True Cd: 0.240132
# 🚗 F_S_WWS_WM_269 → Predicted Cd: 0.237353 | True Cd: 0.234135
# 🚗 F_S_WWS_WM_236 → Predicted Cd: 0.242269 | True Cd: 0.227946
# 🚗 F_S_WWC_WM_413 → Predicted Cd: 0.247058 | True Cd: 0.227937
# 🚗 N_S_WW_WM_207 → Predicted Cd: 0.266463 | True Cd: 0.262366
# 🚗 E_S_WW_WM_133 → Predicted Cd: 0.280753 | True Cd: 0.300096
# 🚗 DrivAer_F_D_WM_WW_1877 → Predicted Cd: 0.311414 | True Cd: 0.330090
# 🚗 DrivAer_F_D_WM_WW_1511 → Predicted Cd: 0.329066 | True Cd: 0.348409
# 🚗 DrivAer_F_D_WM_WW_1522 → Predicted Cd: 0.272738 | True Cd: 0.283654
# 🚗 DrivAer_F_D_WM_WW_3129 → Predicted Cd: 0.314954 | True Cd: 0.335448
# 🚗 DrivAer_F_D_WM_WW_0659 → Predicted Cd: 0.330416 | True Cd: 0.357118
# 🚗 DrivAer_F_D_WM_WW_2570 → Predicted Cd: 0.278524 | True Cd: 0.268848
# 🚗 DrivAer_F_D_WM_WW_0897 → Predicted Cd: 0.330111 | True Cd: 0.346808
# 🚗 DrivAer_F_D_WM_WW_2498 → Predicted Cd: 0.326550 | True Cd: 0.343571
# 🚗 DrivAer_F_D_WM_WW_3794 → Predicted Cd: 0.316340 | True Cd: 0.318851
# 🚗 DrivAer_F_D_WM_WW_2493 → Predicted Cd: 0.293547 | True Cd: 0.306794
# 🚗 DrivAer_F_D_WM_WW_3414 → Predicted Cd: 0.306239 | True Cd: 0.318845
# 🚗 DrivAer_F_D_WM_WW_0278 → Predicted Cd: 0.281510 | True Cd: 0.281367
# 🚗 DrivAer_F_D_WM_WW_2078 → Predicted Cd: 0.330841 | True Cd: 0.362850
# 🚗 DrivAer_F_D_WM_WW_3593 → Predicted Cd: 0.295240 | True Cd: 0.298554
# 🚗 DrivAer_F_D_WM_WW_3751 → Predicted Cd: 0.321358 | True Cd: 0.343827
# 🚗 DrivAer_F_D_WM_WW_3716 → Predicted Cd: 0.274914 | True Cd: 0.270410
# 🚗 DrivAer_F_D_WM_WW_2410 → Predicted Cd: 0.272352 | True Cd: 0.259576
# 🚗 DrivAer_F_D_WM_WW_1356 → Predicted Cd: 0.284171 | True Cd: 0.291029
# 🚗 DrivAer_F_D_WM_WW_0626 → Predicted Cd: 0.333667 | True Cd: 0.368727
# 🚗 DrivAer_F_D_WM_WW_0760 → Predicted Cd: 0.293020 | True Cd: 0.291576
# 🚗 DrivAer_F_D_WM_WW_0496 → Predicted Cd: 0.289677 | True Cd: 0.303043
# 🚗 DrivAer_F_D_WM_WW_1005 → Predicted Cd: 0.319892 | True Cd: 0.336585
# 🚗 DrivAer_F_D_WM_WW_1833 → Predicted Cd: 0.321559 | True Cd: 0.347751
# 🚗 DrivAer_F_D_WM_WW_2815 → Predicted Cd: 0.324621 | True Cd: 0.351835
# 🚗 DrivAer_F_D_WM_WW_3633 → Predicted Cd: 0.289013 | True Cd: 0.279572
# 🚗 DrivAer_F_D_WM_WW_1558 → Predicted Cd: 0.306013 | True Cd: 0.325267
# 🚗 DrivAer_F_D_WM_WW_2366 → Predicted Cd: 0.292940 | True Cd: 0.287416
# 🚗 DrivAer_F_D_WM_WW_1990 → Predicted Cd: 0.329505 | True Cd: 0.361196
# 🚗 DrivAer_F_D_WM_WW_2892 → Predicted Cd: 0.276464 | True Cd: 0.265101
# 🚗 DrivAer_F_D_WM_WW_2621 → Predicted Cd: 0.276505 | True Cd: 0.271297
# 🚗 DrivAer_F_D_WM_WW_0326 → Predicted Cd: 0.293480 | True Cd: 0.299254
# 🚗 DrivAer_F_D_WM_WW_2395 → Predicted Cd: 0.293815 | True Cd: 0.293212
# 🚗 DrivAer_F_D_WM_WW_3120 → Predicted Cd: 0.314880 | True Cd: 0.330247
# 🚗 DrivAer_F_D_WM_WW_2367 → Predicted Cd: 0.317599 | True Cd: 0.316697
# 🚗 DrivAer_F_D_WM_WW_2859 → Predicted Cd: 0.304368 | True Cd: 0.307181
# 🚗 DrivAer_F_D_WM_WW_0470 → Predicted Cd: 0.306702 | True Cd: 0.321640
# 🚗 DrivAer_F_D_WM_WW_1968 → Predicted Cd: 0.334447 | True Cd: 0.370090
# 🚗 DrivAer_F_D_WM_WW_3799 → Predicted Cd: 0.294965 | True Cd: 0.293239
# 🚗 DrivAer_F_D_WM_WW_1236 → Predicted Cd: 0.287533 | True Cd: 0.281978
# 🚗 DrivAer_F_D_WM_WW_2738 → Predicted Cd: 0.282946 | True Cd: 0.272624
# 🚗 DrivAer_F_D_WM_WW_1340 → Predicted Cd: 0.288143 | True Cd: 0.296847
# 🚗 DrivAer_F_D_WM_WW_2299 → Predicted Cd: 0.320119 | True Cd: 0.337163
# 🚗 DrivAer_F_D_WM_WW_1934 → Predicted Cd: 0.290551 | True Cd: 0.290419
# 🚗 DrivAer_F_D_WM_WW_3757 → Predicted Cd: 0.334186 | True Cd: 0.365985
# 🚗 DrivAer_F_D_WM_WW_0350 → Predicted Cd: 0.323178 | True Cd: 0.339595
# 🚗 DrivAer_F_D_WM_WW_0767 → Predicted Cd: 0.316169 | True Cd: 0.322089
# 🚗 DrivAer_F_D_WM_WW_2999 → Predicted Cd: 0.325771 | True Cd: 0.346509
# 🚗 DrivAer_F_D_WM_WW_1202 → Predicted Cd: 0.337771 | True Cd: 0.374640
# 🚗 DrivAer_F_D_WM_WW_3588 → Predicted Cd: 0.302530 | True Cd: 0.306623
# 🚗 DrivAer_F_D_WM_WW_1866 → Predicted Cd: 0.318780 | True Cd: 0.331217
# 🚗 DrivAer_F_D_WM_WW_3396 → Predicted Cd: 0.294385 | True Cd: 0.293137
# 🚗 DrivAer_F_D_WM_WW_2525 → Predicted Cd: 0.331664 | True Cd: 0.364868
# 🚗 DrivAer_F_D_WM_WW_1782 → Predicted Cd: 0.309689 | True Cd: 0.312861
# 🚗 DrivAer_F_D_WM_WW_1103 → Predicted Cd: 0.318223 | True Cd: 0.348039
# 🚗 DrivAer_F_D_WM_WW_1829 → Predicted Cd: 0.315307 | True Cd: 0.330604
# 🚗 DrivAer_F_D_WM_WW_3549 → Predicted Cd: 0.289747 | True Cd: 0.295588
# 🚗 DrivAer_F_D_WM_WW_2010 → Predicted Cd: 0.288321 | True Cd: 0.283061
# 🚗 DrivAer_F_D_WM_WW_0214 → Predicted Cd: 0.299102 | True Cd: 0.306986
# 🚗 DrivAer_F_D_WM_WW_0454 → Predicted Cd: 0.283362 | True Cd: 0.275996
# 🚗 DrivAer_F_D_WM_WW_0072 → Predicted Cd: 0.306294 | True Cd: 0.319209
# 🚗 DrivAer_F_D_WM_WW_0877 → Predicted Cd: 0.281993 | True Cd: 0.281409
# 🚗 DrivAer_F_D_WM_WW_0224 → Predicted Cd: 0.324970 | True Cd: 0.348906
# 🚗 DrivAer_F_D_WM_WW_0019 → Predicted Cd: 0.292663 | True Cd: 0.301720
# 🚗 DrivAer_F_D_WM_WW_3412 → Predicted Cd: 0.330905 | True Cd: 0.359331
# 🚗 DrivAer_F_D_WM_WW_3861 → Predicted Cd: 0.324018 | True Cd: 0.346693
# 🚗 DrivAer_F_D_WM_WW_3518 → Predicted Cd: 0.305316 | True Cd: 0.315273
# 🚗 DrivAer_F_D_WM_WW_0931 → Predicted Cd: 0.288298 | True Cd: 0.297197
# 🚗 DrivAer_F_D_WM_WW_2018 → Predicted Cd: 0.323219 | True Cd: 0.331107
# 🚗 DrivAer_F_D_WM_WW_3722 → Predicted Cd: 0.339608 | True Cd: 0.370384
# 🚗 DrivAer_F_D_WM_WW_3881 → Predicted Cd: 0.326350 | True Cd: 0.358440
# 🚗 DrivAer_F_D_WM_WW_2369 → Predicted Cd: 0.326647 | True Cd: 0.341477
# 🚗 DrivAer_F_D_WM_WW_0058 → Predicted Cd: 0.274400 | True Cd: 0.278271
# 🚗 DrivAer_F_D_WM_WW_0196 → Predicted Cd: 0.282901 | True Cd: 0.289714
# 🚗 DrivAer_F_D_WM_WW_3619 → Predicted Cd: 0.310238 | True Cd: 0.330919
# 🚗 DrivAer_F_D_WM_WW_1407 → Predicted Cd: 0.273953 | True Cd: 0.273954
# 🚗 DrivAer_F_D_WM_WW_0617 → Predicted Cd: 0.328957 | True Cd: 0.354241
# 🚗 DrivAer_F_D_WM_WW_1141 → Predicted Cd: 0.281307 | True Cd: 0.284052
# 🚗 DrivAer_F_D_WM_WW_3561 → Predicted Cd: 0.305142 | True Cd: 0.324966
# 🚗 DrivAer_F_D_WM_WW_0322 → Predicted Cd: 0.290075 | True Cd: 0.300227
# 🚗 DrivAer_F_D_WM_WW_3500 → Predicted Cd: 0.293592 | True Cd: 0.295381
# 🚗 DrivAer_F_D_WM_WW_1291 → Predicted Cd: 0.297002 | True Cd: 0.303754
# 🚗 DrivAer_F_D_WM_WW_1735 → Predicted Cd: 0.270748 | True Cd: 0.274072
# 🚗 DrivAer_F_D_WM_WW_1889 → Predicted Cd: 0.274576 | True Cd: 0.279024
# 🚗 DrivAer_F_D_WM_WW_3915 → Predicted Cd: 0.285481 | True Cd: 0.285572
# 🚗 DrivAer_F_D_WM_WW_1186 → Predicted Cd: 0.323452 | True Cd: 0.358007
# 🚗 DrivAer_F_D_WM_WW_1113 → Predicted Cd: 0.293314 | True Cd: 0.295376
# 🚗 DrivAer_F_D_WM_WW_3908 → Predicted Cd: 0.316228 | True Cd: 0.335354
# 🚗 DrivAer_F_D_WM_WW_1174 → Predicted Cd: 0.314215 | True Cd: 0.323997
# 🚗 DrivAer_F_D_WM_WW_2286 → Predicted Cd: 0.284920 | True Cd: 0.299085
# 🚗 DrivAer_F_D_WM_WW_1578 → Predicted Cd: 0.302928 | True Cd: 0.313848
# 🚗 DrivAer_F_D_WM_WW_1437 → Predicted Cd: 0.314783 | True Cd: 0.343850
# 🚗 DrivAer_F_D_WM_WW_0218 → Predicted Cd: 0.332819 | True Cd: 0.368277
# 🚗 DrivAer_F_D_WM_WW_1565 → Predicted Cd: 0.286013 | True Cd: 0.289070
# 🚗 DrivAer_F_D_WM_WW_3959 → Predicted Cd: 0.314099 | True Cd: 0.334819
# 🚗 DrivAer_F_D_WM_WW_1372 → Predicted Cd: 0.307926 | True Cd: 0.322442
# 🚗 DrivAer_F_D_WM_WW_0160 → Predicted Cd: 0.319159 | True Cd: 0.319873
# 🚗 DrivAer_F_D_WM_WW_2336 → Predicted Cd: 0.283312 | True Cd: 0.296960
# 🚗 DrivAer_F_D_WM_WW_1991 → Predicted Cd: 0.280336 | True Cd: 0.270148
# 🚗 DrivAer_F_D_WM_WW_0516 → Predicted Cd: 0.277004 | True Cd: 0.273754
# 🚗 DrivAer_F_D_WM_WW_2393 → Predicted Cd: 0.317449 | True Cd: 0.335220
# 🚗 DrivAer_F_D_WM_WW_3896 → Predicted Cd: 0.273733 | True Cd: 0.274768
# 🚗 DrivAer_F_D_WM_WW_3615 → Predicted Cd: 0.276282 | True Cd: 0.272901
# 🚗 DrivAer_F_D_WM_WW_1860 → Predicted Cd: 0.277299 | True Cd: 0.270636
# 🚗 DrivAer_F_D_WM_WW_1405 → Predicted Cd: 0.305305 | True Cd: 0.317665
# 🚗 DrivAer_F_D_WM_WW_1566 → Predicted Cd: 0.320512 | True Cd: 0.338534
# 🚗 DrivAer_F_D_WM_WW_1550 → Predicted Cd: 0.276914 | True Cd: 0.276773
# 🚗 DrivAer_F_D_WM_WW_1712 → Predicted Cd: 0.305957 | True Cd: 0.319621
# 🚗 DrivAer_F_D_WM_WW_0374 → Predicted Cd: 0.300354 | True Cd: 0.305083
# 🚗 DrivAer_F_D_WM_WW_1414 → Predicted Cd: 0.279743 | True Cd: 0.272869
# 🚗 DrivAer_F_D_WM_WW_2354 → Predicted Cd: 0.303793 | True Cd: 0.304062
# 🚗 DrivAer_F_D_WM_WW_2608 → Predicted Cd: 0.326122 | True Cd: 0.343179
# 🚗 DrivAer_F_D_WM_WW_0685 → Predicted Cd: 0.305878 | True Cd: 0.331754
# 🚗 DrivAer_F_D_WM_WW_0437 → Predicted Cd: 0.289006 | True Cd: 0.291185
# 🚗 DrivAer_F_D_WM_WW_3486 → Predicted Cd: 0.323170 | True Cd: 0.336473
# 🚗 DrivAer_F_D_WM_WW_0283 → Predicted Cd: 0.326947 | True Cd: 0.343125
# 🚗 DrivAer_F_D_WM_WW_3058 → Predicted Cd: 0.314643 | True Cd: 0.323403
# 🚗 DrivAer_F_D_WM_WW_3512 → Predicted Cd: 0.303968 | True Cd: 0.310903
# 🚗 DrivAer_F_D_WM_WW_0675 → Predicted Cd: 0.300597 | True Cd: 0.298563
# 🚗 DrivAer_F_D_WM_WW_3487 → Predicted Cd: 0.324211 | True Cd: 0.340393
# 🚗 DrivAer_F_D_WM_WW_0212 → Predicted Cd: 0.322749 | True Cd: 0.341700
# 🚗 DrivAer_F_D_WM_WW_1792 → Predicted Cd: 0.322693 | True Cd: 0.337917
# 🚗 DrivAer_F_D_WM_WW_0562 → Predicted Cd: 0.283250 | True Cd: 0.286175
# 🚗 DrivAer_F_D_WM_WW_1019 → Predicted Cd: 0.312842 | True Cd: 0.335890
# 🚗 DrivAer_F_D_WM_WW_3986 → Predicted Cd: 0.308718 | True Cd: 0.318311
# 🚗 DrivAer_F_D_WM_WW_1278 → Predicted Cd: 0.287178 | True Cd: 0.295968
# 🚗 DrivAer_F_D_WM_WW_0261 → Predicted Cd: 0.287040 | True Cd: 0.294867
# 🚗 DrivAer_F_D_WM_WW_2706 → Predicted Cd: 0.287697 | True Cd: 0.308581
# 🚗 DrivAer_F_D_WM_WW_0255 → Predicted Cd: 0.279146 | True Cd: 0.276315
# 🚗 DrivAer_F_D_WM_WW_1655 → Predicted Cd: 0.278546 | True Cd: 0.281332
# 🚗 DrivAer_F_D_WM_WW_3932 → Predicted Cd: 0.312110 | True Cd: 0.323921
# 🚗 DrivAer_F_D_WM_WW_0182 → Predicted Cd: 0.320493 | True Cd: 0.335797
# 🚗 DrivAer_F_D_WM_WW_3202 → Predicted Cd: 0.281911 | True Cd: 0.280008
# 🚗 DrivAer_F_D_WM_WW_3221 → Predicted Cd: 0.302464 | True Cd: 0.321304
# 🚗 DrivAer_F_D_WM_WW_3195 → Predicted Cd: 0.278626 | True Cd: 0.284525
# 🚗 DrivAer_F_D_WM_WW_2837 → Predicted Cd: 0.297736 | True Cd: 0.313789
# 🚗 DrivAer_F_D_WM_WW_1382 → Predicted Cd: 0.306044 | True Cd: 0.327111
# 🚗 DrivAer_F_D_WM_WW_0896 → Predicted Cd: 0.315919 | True Cd: 0.337591
# 🚗 DrivAer_F_D_WM_WW_0601 → Predicted Cd: 0.283467 | True Cd: 0.286496
# 🚗 DrivAer_F_D_WM_WW_1699 → Predicted Cd: 0.289198 | True Cd: 0.286580
# 🚗 DrivAer_F_D_WM_WW_2307 → Predicted Cd: 0.311325 | True Cd: 0.326761
# 🚗 DrivAer_F_D_WM_WW_0448 → Predicted Cd: 0.282297 | True Cd: 0.284090
# 🚗 DrivAer_F_D_WM_WW_0262 → Predicted Cd: 0.332790 | True Cd: 0.365336
# 🚗 DrivAer_F_D_WM_WW_2633 → Predicted Cd: 0.297224 | True Cd: 0.303118
# 🚗 DrivAer_F_D_WM_WW_0587 → Predicted Cd: 0.309414 | True Cd: 0.322169
# 🚗 DrivAer_F_D_WM_WW_2680 → Predicted Cd: 0.305413 | True Cd: 0.322518
# 🚗 DrivAer_F_D_WM_WW_0615 → Predicted Cd: 0.280812 | True Cd: 0.273862
# 🚗 DrivAer_F_D_WM_WW_0370 → Predicted Cd: 0.285564 | True Cd: 0.280053
# 🚗 DrivAer_F_D_WM_WW_1438 → Predicted Cd: 0.319256 | True Cd: 0.337867
# 🚗 DrivAer_F_D_WM_WW_0027 → Predicted Cd: 0.273305 | True Cd: 0.260413
# 🚗 DrivAer_F_D_WM_WW_1243 → Predicted Cd: 0.304859 | True Cd: 0.313721
# 🚗 DrivAer_F_D_WM_WW_3866 → Predicted Cd: 0.282871 | True Cd: 0.290030
# 🚗 DrivAer_F_D_WM_WW_2441 → Predicted Cd: 0.326314 | True Cd: 0.359428
# 🚗 DrivAer_F_D_WM_WW_2781 → Predicted Cd: 0.282848 | True Cd: 0.291054
# 🚗 DrivAer_F_D_WM_WW_3962 → Predicted Cd: 0.286920 | True Cd: 0.292515
# 🚗 DrivAer_F_D_WM_WW_3525 → Predicted Cd: 0.272277 | True Cd: 0.260101
# 🚗 DrivAer_F_D_WM_WW_1385 → Predicted Cd: 0.281458 | True Cd: 0.284131
# 🚗 DrivAer_F_D_WM_WW_0696 → Predicted Cd: 0.334787 | True Cd: 0.371866
# 🚗 DrivAer_F_D_WM_WW_1804 → Predicted Cd: 0.325083 | True Cd: 0.347805
# 🚗 DrivAer_F_D_WM_WW_1410 → Predicted Cd: 0.287568 | True Cd: 0.285319
# 🚗 DrivAer_F_D_WM_WW_3570 → Predicted Cd: 0.288619 | True Cd: 0.287999
# 🚗 DrivAer_F_D_WM_WW_3531 → Predicted Cd: 0.304492 | True Cd: 0.317622
# 🚗 DrivAer_F_D_WM_WW_1188 → Predicted Cd: 0.309781 | True Cd: 0.324077
# 🚗 DrivAer_F_D_WM_WW_3706 → Predicted Cd: 0.326666 | True Cd: 0.347940
# 🚗 DrivAer_F_D_WM_WW_2709 → Predicted Cd: 0.287318 | True Cd: 0.291359
# 🚗 DrivAer_F_D_WM_WW_2204 → Predicted Cd: 0.287139 | True Cd: 0.290394
# 🚗 DrivAer_F_D_WM_WW_3977 → Predicted Cd: 0.292671 | True Cd: 0.295254
# 🚗 DrivAer_F_D_WM_WW_3539 → Predicted Cd: 0.323850 | True Cd: 0.336438
# 🚗 DrivAer_F_D_WM_WW_2024 → Predicted Cd: 0.294099 | True Cd: 0.303535
# 🚗 DrivAer_F_D_WM_WW_0179 → Predicted Cd: 0.292645 | True Cd: 0.289183
# 🚗 DrivAer_F_D_WM_WW_3235 → Predicted Cd: 0.272242 | True Cd: 0.268837
# 🚗 DrivAer_F_D_WM_WW_3315 → Predicted Cd: 0.287106 | True Cd: 0.290929
# 🚗 DrivAer_F_D_WM_WW_2318 → Predicted Cd: 0.316253 | True Cd: 0.338875
# 🚗 DrivAer_F_D_WM_WW_2432 → Predicted Cd: 0.304409 | True Cd: 0.317462
# 🚗 DrivAer_F_D_WM_WW_2390 → Predicted Cd: 0.305074 | True Cd: 0.312200
# 🚗 DrivAer_F_D_WM_WW_1764 → Predicted Cd: 0.276894 | True Cd: 0.280660
# 🚗 DrivAer_F_D_WM_WW_1958 → Predicted Cd: 0.272502 | True Cd: 0.269156
# 🚗 DrivAer_F_D_WM_WW_1808 → Predicted Cd: 0.298631 | True Cd: 0.306658
# 🚗 DrivAer_F_D_WM_WW_1122 → Predicted Cd: 0.281435 | True Cd: 0.284930
# 🚗 DrivAer_F_D_WM_WW_1629 → Predicted Cd: 0.286084 | True Cd: 0.278944
# 🚗 DrivAer_F_D_WM_WW_0823 → Predicted Cd: 0.296606 | True Cd: 0.309105
# 🚗 DrivAer_F_D_WM_WW_0033 → Predicted Cd: 0.306874 | True Cd: 0.312731
# 🚗 DrivAer_F_D_WM_WW_1806 → Predicted Cd: 0.281049 | True Cd: 0.283305
# 🚗 DrivAer_F_D_WM_WW_0649 → Predicted Cd: 0.329515 | True Cd: 0.343467
# 🚗 DrivAer_F_D_WM_WW_0209 → Predicted Cd: 0.288118 | True Cd: 0.298174
# 🚗 DrivAer_F_D_WM_WW_0984 → Predicted Cd: 0.317697 | True Cd: 0.338159
# 🚗 DrivAer_F_D_WM_WW_1040 → Predicted Cd: 0.317083 | True Cd: 0.330889
# 🚗 DrivAer_F_D_WM_WW_3944 → Predicted Cd: 0.304636 | True Cd: 0.313989
# 🚗 DrivAer_F_D_WM_WW_1302 → Predicted Cd: 0.300443 | True Cd: 0.308663
# 🚗 DrivAer_F_D_WM_WW_0223 → Predicted Cd: 0.315171 | True Cd: 0.323637
# ...
# 🚗 DrivAer_F_D_WM_WW_1571 → Predicted Cd: 0.310249 | True Cd: 0.326052
# 🚗 DrivAer_F_D_WM_WW_3108 → Predicted Cd: 0.284223 | True Cd: 0.294113
# 🚗 DrivAer_F_D_WM_WW_1158 → Predicted Cd: 0.315355 | True Cd: 0.332198
# 🚗 DrivAer_F_D_WM_WW_2708 → Predicted Cd: 0.281351 | True Cd: 0.285465
# 🚗 DrivAer_F_D_WM_WW_0455 → Predicted Cd: 0.309158 | True Cd: 0.315370
# 🚗 DrivAer_F_D_WM_WW_2117 → Predicted Cd: 0.283128 | True Cd: 0.286705
# 🚗 DrivAer_F_D_WM_WW_3740 → Predicted Cd: 0.284458 | True Cd: 0.286429
# 🚗 DrivAer_F_D_WM_WW_0473 → Predicted Cd: 0.313691 | True Cd: 0.324470
# 🚗 DrivAer_F_D_WM_WW_1729 → Predicted Cd: 0.292010 | True Cd: 0.304461
# 🚗 DrivAer_F_D_WM_WW_0221 → Predicted Cd: 0.294487 | True Cd: 0.296123
# 🚗 DrivAer_F_D_WM_WW_3941 → Predicted Cd: 0.314962 | True Cd: 0.334972
# 🚗 DrivAer_F_D_WM_WW_1273 → Predicted Cd: 0.316457 | True Cd: 0.331877
# 🚗 DrivAer_F_D_WM_WW_1231 → Predicted Cd: 0.291469 | True Cd: 0.308098
# 🚗 DrivAer_F_D_WM_WW_3872 → Predicted Cd: 0.303781 | True Cd: 0.309866
# 🚗 DrivAer_F_D_WM_WW_3523 → Predicted Cd: 0.305919 | True Cd: 0.316318
# 🚗 DrivAer_F_D_WM_WW_2990 → Predicted Cd: 0.303823 | True Cd: 0.322350
# 🚗 DrivAer_F_D_WM_WW_2266 → Predicted Cd: 0.278098 | True Cd: 0.278037
# 🚗 DrivAer_F_D_WM_WW_0915 → Predicted Cd: 0.320057 | True Cd: 0.331900
# 🚗 DrivAer_F_D_WM_WW_1123 → Predicted Cd: 0.292141 | True Cd: 0.302329
# 🚗 DrivAer_F_D_WM_WW_3277 → Predicted Cd: 0.288549 | True Cd: 0.283875
# 🚗 DrivAer_F_D_WM_WW_3621 → Predicted Cd: 0.283956 | True Cd: 0.289042
# 🚗 DrivAer_F_D_WM_WW_3600 → Predicted Cd: 0.284285 | True Cd: 0.286018
# 🚗 DrivAer_F_D_WM_WW_3288 → Predicted Cd: 0.272400 | True Cd: 0.261689
# 🚗 DrivAer_F_D_WM_WW_2527 → Predicted Cd: 0.302988 | True Cd: 0.316238
# 🚗 DrivAer_F_D_WM_WW_2816 → Predicted Cd: 0.284809 | True Cd: 0.286010
# 🚗 DrivAer_F_D_WM_WW_3557 → Predicted Cd: 0.300973 | True Cd: 0.311010
# 🚗 DrivAer_F_D_WM_WW_3635 → Predicted Cd: 0.288630 | True Cd: 0.300921
# 🚗 DrivAer_F_D_WM_WW_2274 → Predicted Cd: 0.298252 | True Cd: 0.312251
# 🚗 DrivAer_F_D_WM_WW_2971 → Predicted Cd: 0.335903 | True Cd: 0.364883
# 🚗 DrivAer_F_D_WM_WW_1132 → Predicted Cd: 0.287174 | True Cd: 0.285883
# 🚗 DrivAer_F_D_WM_WW_3967 → Predicted Cd: 0.289320 | True Cd: 0.297320
# 🚗 DrivAer_F_D_WM_WW_1055 → Predicted Cd: 0.313987 | True Cd: 0.319205
# 🚗 DrivAer_F_D_WM_WW_0570 → Predicted Cd: 0.301281 | True Cd: 0.322650
# 🚗 DrivAer_F_D_WM_WW_1073 → Predicted Cd: 0.279894 | True Cd: 0.269412
# 🚗 DrivAer_F_D_WM_WW_3433 → Predicted Cd: 0.288614 | True Cd: 0.297098
# 🚗 DrivAer_F_D_WM_WW_2050 → Predicted Cd: 0.282636 | True Cd: 0.274935
# 🚗 DrivAer_F_D_WM_WW_1221 → Predicted Cd: 0.328860 | True Cd: 0.356035
# 🚗 DrivAer_F_D_WM_WW_2203 → Predicted Cd: 0.314332 | True Cd: 0.327443
# 🚗 DrivAer_F_D_WM_WW_0418 → Predicted Cd: 0.293297 | True Cd: 0.305613
# 🚗 DrivAer_F_D_WM_WW_2583 → Predicted Cd: 0.281959 | True Cd: 0.275496
# 🚗 DrivAer_F_D_WM_WW_1087 → Predicted Cd: 0.275150 | True Cd: 0.270432
# 🚗 DrivAer_F_D_WM_WW_0434 → Predicted Cd: 0.302829 | True Cd: 0.318351
# 🚗 DrivAer_F_D_WM_WW_0809 → Predicted Cd: 0.305118 | True Cd: 0.315397
# 🚗 DrivAer_F_D_WM_WW_3443 → Predicted Cd: 0.286438 | True Cd: 0.297666
# 🚗 DrivAer_F_D_WM_WW_2878 → Predicted Cd: 0.324718 | True Cd: 0.351063
# 🚗 DrivAer_F_D_WM_WW_3738 → Predicted Cd: 0.316521 | True Cd: 0.335928
# 🚗 DrivAer_F_D_WM_WW_0199 → Predicted Cd: 0.281639 | True Cd: 0.283370
# 🚗 DrivAer_F_D_WM_WW_2839 → Predicted Cd: 0.281689 | True Cd: 0.284878
# 🚗 DrivAer_F_D_WM_WW_1972 → Predicted Cd: 0.328120 | True Cd: 0.354046
# 🚗 DrivAer_F_D_WM_WW_2121 → Predicted Cd: 0.320430 | True Cd: 0.348928
# 🚗 DrivAer_F_D_WM_WW_0112 → Predicted Cd: 0.286279 | True Cd: 0.295575
# 🚗 DrivAer_F_D_WM_WW_3474 → Predicted Cd: 0.273363 | True Cd: 0.268362
# 🚗 DrivAer_F_D_WM_WW_3225 → Predicted Cd: 0.326513 | True Cd: 0.359753
# 🚗 DrivAer_F_D_WM_WW_2553 → Predicted Cd: 0.278051 | True Cd: 0.280480
# 🚗 DrivAer_F_D_WM_WW_0726 → Predicted Cd: 0.274328 | True Cd: 0.263741
# 🚗 DrivAer_F_D_WM_WW_2551 → Predicted Cd: 0.321792 | True Cd: 0.353784
# 🚗 DrivAer_F_D_WM_WW_0855 → Predicted Cd: 0.282740 | True Cd: 0.291337
# 🚗 DrivAer_F_D_WM_WW_0144 → Predicted Cd: 0.280221 | True Cd: 0.282164
# 🚗 DrivAer_F_D_WM_WW_1126 → Predicted Cd: 0.315034 | True Cd: 0.330906
# 🚗 DrivAer_F_D_WM_WW_2301 → Predicted Cd: 0.315171 | True Cd: 0.330490
# 🚗 DrivAer_F_D_WM_WW_3869 → Predicted Cd: 0.315629 | True Cd: 0.336072
# 🚗 DrivAer_F_D_WM_WW_1065 → Predicted Cd: 0.314493 | True Cd: 0.330281
# 🚗 DrivAer_F_D_WM_WW_0948 → Predicted Cd: 0.299363 | True Cd: 0.303302
# 🚗 DrivAer_F_D_WM_WW_3998 → Predicted Cd: 0.288281 | True Cd: 0.288301
# 🚗 DrivAer_F_D_WM_WW_0386 → Predicted Cd: 0.312394 | True Cd: 0.325873
# 🚗 DrivAer_F_D_WM_WW_1183 → Predicted Cd: 0.289249 | True Cd: 0.295042
# 🚗 DrivAer_F_D_WM_WW_2365 → Predicted Cd: 0.302611 | True Cd: 0.326313
# 🚗 DrivAer_F_D_WM_WW_2711 → Predicted Cd: 0.319896 | True Cd: 0.343600
# 🚗 DrivAer_F_D_WM_WW_1603 → Predicted Cd: 0.292313 | True Cd: 0.294269
# 🚗 DrivAer_F_D_WM_WW_2250 → Predicted Cd: 0.314906 | True Cd: 0.331599
# 🚗 DrivAer_F_D_WM_WW_0165 → Predicted Cd: 0.327671 | True Cd: 0.347742
# 🚗 DrivAer_F_D_WM_WW_1489 → Predicted Cd: 0.271843 | True Cd: 0.262123
# 🚗 DrivAer_F_D_WM_WW_3867 → Predicted Cd: 0.314379 | True Cd: 0.335447
# 🚗 DrivAer_F_D_WM_WW_2035 → Predicted Cd: 0.280424 | True Cd: 0.285391
# 🚗 DrivAer_F_D_WM_WW_2968 → Predicted Cd: 0.292646 | True Cd: 0.298124
# 🚗 DrivAer_F_D_WM_WW_2572 → Predicted Cd: 0.286530 | True Cd: 0.292935
# 🚗 DrivAer_F_D_WM_WW_2188 → Predicted Cd: 0.288713 | True Cd: 0.299881
# 🚗 DrivAer_F_D_WM_WW_2693 → Predicted Cd: 0.282404 | True Cd: 0.278666
# 🚗 DrivAer_F_D_WM_WW_0187 → Predicted Cd: 0.276566 | True Cd: 0.276648
# 🚗 DrivAer_F_D_WM_WW_2549 → Predicted Cd: 0.283859 | True Cd: 0.284627
# 🚗 DrivAer_F_D_WM_WW_1850 → Predicted Cd: 0.305753 | True Cd: 0.337058
# 🚗 DrivAer_F_D_WM_WW_1954 → Predicted Cd: 0.306646 | True Cd: 0.321985
# 🚗 DrivAer_F_D_WM_WW_1303 → Predicted Cd: 0.279037 | True Cd: 0.277487
# 🚗 DrivAer_F_D_WM_WW_2327 → Predicted Cd: 0.284591 | True Cd: 0.291194
# 🚗 DrivAer_F_D_WM_WW_0260 → Predicted Cd: 0.302297 | True Cd: 0.312891
# 🚗 DrivAer_F_D_WM_WW_0762 → Predicted Cd: 0.288684 | True Cd: 0.296242
# 🚗 DrivAer_F_D_WM_WW_3889 → Predicted Cd: 0.278021 | True Cd: 0.270215
# 🚗 DrivAer_F_D_WM_WW_0178 → Predicted Cd: 0.292572 | True Cd: 0.301399
# 🚗 DrivAer_F_D_WM_WW_1743 → Predicted Cd: 0.271509 | True Cd: 0.254265
# 🚗 DrivAer_F_D_WM_WW_1268 → Predicted Cd: 0.318274 | True Cd: 0.341880
# 🚗 DrivAer_F_D_WM_WW_2891 → Predicted Cd: 0.324011 | True Cd: 0.343436
# 🚗 DrivAer_F_D_WM_WW_3439 → Predicted Cd: 0.308610 | True Cd: 0.318578
# 🚗 DrivAer_F_D_WM_WW_1011 → Predicted Cd: 0.305724 | True Cd: 0.322469
# 🚗 DrivAer_F_D_WM_WW_2329 → Predicted Cd: 0.293325 | True Cd: 0.299234
# 🚗 DrivAer_F_D_WM_WW_2199 → Predicted Cd: 0.276516 | True Cd: 0.270131
# 🚗 DrivAer_F_D_WM_WW_0443 → Predicted Cd: 0.319217 | True Cd: 0.329862
# 🚗 DrivAer_F_D_WM_WW_2577 → Predicted Cd: 0.322977 | True Cd: 0.346059
# 🚗 DrivAer_F_D_WM_WW_3626 → Predicted Cd: 0.321271 | True Cd: 0.339239
# 🚗 DrivAer_F_D_WM_WW_2205 → Predicted Cd: 0.278699 | True Cd: 0.276970
# 🚗 DrivAer_F_D_WM_WW_0817 → Predicted Cd: 0.330041 | True Cd: 0.348336
# 🚗 DrivAer_F_D_WM_WW_1060 → Predicted Cd: 0.275780 | True Cd: 0.261116
# 🚗 DrivAer_F_D_WM_WW_1965 → Predicted Cd: 0.325680 | True Cd: 0.352052
# 🚗 DrivAer_F_D_WM_WW_1220 → Predicted Cd: 0.293506 | True Cd: 0.305931
# 🚗 DrivAer_F_D_WM_WW_2795 → Predicted Cd: 0.287550 | True Cd: 0.295040
# 🚗 DrivAer_F_D_WM_WW_2278 → Predicted Cd: 0.287062 | True Cd: 0.278430
# 🚗 DrivAer_F_D_WM_WW_0484 → Predicted Cd: 0.308743 | True Cd: 0.320682
# 🚗 DrivAer_F_D_WM_WW_1082 → Predicted Cd: 0.281029 | True Cd: 0.279997
# 🚗 DrivAer_F_D_WM_WW_1093 → Predicted Cd: 0.320006 | True Cd: 0.335041
# 🚗 DrivAer_F_D_WM_WW_0972 → Predicted Cd: 0.334624 | True Cd: 0.364320
# 🚗 DrivAer_F_D_WM_WW_0935 → Predicted Cd: 0.310175 | True Cd: 0.322978
# 🚗 DrivAer_F_D_WM_WW_2632 → Predicted Cd: 0.300098 | True Cd: 0.312216
# 🚗 DrivAer_F_D_WM_WW_2012 → Predicted Cd: 0.318052 | True Cd: 0.335657
# 🚗 DrivAer_F_D_WM_WW_2201 → Predicted Cd: 0.273306 | True Cd: 0.267621
# 🚗 DrivAer_F_D_WM_WW_3442 → Predicted Cd: 0.320506 | True Cd: 0.336569
# 🚗 DrivAer_F_D_WM_WW_1865 → Predicted Cd: 0.311937 | True Cd: 0.325175
# 🚗 DrivAer_F_D_WM_WW_2340 → Predicted Cd: 0.318026 | True Cd: 0.341497
# 🚗 DrivAer_F_D_WM_WW_2437 → Predicted Cd: 0.314217 | True Cd: 0.326220
# 🚗 DrivAer_F_D_WM_WW_2097 → Predicted Cd: 0.307088 | True Cd: 0.318602
# 🚗 DrivAer_F_D_WM_WW_0468 → Predicted Cd: 0.323231 | True Cd: 0.332293
# 🚗 DrivAer_F_D_WM_WW_3342 → Predicted Cd: 0.323427 | True Cd: 0.350144
# 🚗 DrivAer_F_D_WM_WW_1577 → Predicted Cd: 0.333821 | True Cd: 0.356822
# 🚗 DrivAer_F_D_WM_WW_1785 → Predicted Cd: 0.321109 | True Cd: 0.344509
# 🚗 DrivAer_F_D_WM_WW_0014 → Predicted Cd: 0.279411 | True Cd: 0.280423
# 🚗 DrivAer_F_D_WM_WW_1119 → Predicted Cd: 0.290117 | True Cd: 0.305544
# 🚗 DrivAer_F_D_WM_WW_3057 → Predicted Cd: 0.330718 | True Cd: 0.355598
# 🚗 DrivAer_F_D_WM_WW_1601 → Predicted Cd: 0.294275 | True Cd: 0.293888
# 🚗 DrivAer_F_D_WM_WW_2401 → Predicted Cd: 0.275741 | True Cd: 0.272976
# 🚗 DrivAer_F_D_WM_WW_3377 → Predicted Cd: 0.322310 | True Cd: 0.332501
# 🚗 DrivAer_F_D_WM_WW_1921 → Predicted Cd: 0.282366 | True Cd: 0.282143
# 🚗 DrivAer_F_D_WM_WW_0142 → Predicted Cd: 0.291312 | True Cd: 0.299908
# 🚗 DrivAer_F_D_WM_WW_0577 → Predicted Cd: 0.304711 | True Cd: 0.327992
# 🚗 DrivAer_F_D_WM_WW_1035 → Predicted Cd: 0.325818 | True Cd: 0.348377
# 🚗 DrivAer_F_D_WM_WW_2766 → Predicted Cd: 0.292600 | True Cd: 0.299788
# 🚗 DrivAer_F_D_WM_WW_2776 → Predicted Cd: 0.326912 | True Cd: 0.345743
# 🚗 DrivAer_F_D_WM_WW_0920 → Predicted Cd: 0.321616 | True Cd: 0.343318
# 🚗 DrivAer_F_D_WM_WW_1551 → Predicted Cd: 0.274478 | True Cd: 0.274612
# 🚗 DrivAer_F_D_WM_WW_3255 → Predicted Cd: 0.289774 | True Cd: 0.291044
# 🚗 DrivAer_F_D_WM_WW_3755 → Predicted Cd: 0.289687 | True Cd: 0.286684
# 🚗 DrivAer_F_D_WM_WW_2425 → Predicted Cd: 0.282660 | True Cd: 0.285381
# 🚗 DrivAer_F_D_WM_WW_2974 → Predicted Cd: 0.319883 | True Cd: 0.345871
# 🚗 DrivAer_F_D_WM_WW_0945 → Predicted Cd: 0.287985 | True Cd: 0.286304
# 🚗 DrivAer_F_D_WM_WW_1818 → Predicted Cd: 0.275321 | True Cd: 0.275201
# 🚗 DrivAer_F_D_WM_WW_0782 → Predicted Cd: 0.328289 | True Cd: 0.357827
# 🚗 DrivAer_F_D_WM_WW_2989 → Predicted Cd: 0.286721 | True Cd: 0.290791
# 🚗 DrivAer_F_D_WM_WW_3404 → Predicted Cd: 0.288661 | True Cd: 0.299967
# 🚗 DrivAer_F_D_WM_WW_3415 → Predicted Cd: 0.295738 | True Cd: 0.305132
# 🚗 DrivAer_F_D_WM_WW_0687 → Predicted Cd: 0.307504 | True Cd: 0.327624
# 🚗 DrivAer_F_D_WM_WW_1924 → Predicted Cd: 0.293161 | True Cd: 0.297894
# 🚗 DrivAer_F_D_WM_WW_2808 → Predicted Cd: 0.286917 | True Cd: 0.287282
# 🚗 DrivAer_F_D_WM_WW_3958 → Predicted Cd: 0.293320 | True Cd: 0.299975
# 🚗 DrivAer_F_D_WM_WW_0741 → Predicted Cd: 0.302319 | True Cd: 0.314513
# 🚗 DrivAer_F_D_WM_WW_0960 → Predicted Cd: 0.315674 | True Cd: 0.342629
# 🚗 DrivAer_F_D_WM_WW_1854 → Predicted Cd: 0.286260 | True Cd: 0.287742
# 🚗 DrivAer_F_D_WM_WW_3245 → Predicted Cd: 0.317035 | True Cd: 0.334234
# 🚗 DrivAer_F_D_WM_WW_2831 → Predicted Cd: 0.317749 | True Cd: 0.346260
# 🚗 DrivAer_F_D_WM_WW_0380 → Predicted Cd: 0.312459 | True Cd: 0.318575
# 🚗 DrivAer_F_D_WM_WW_0957 → Predicted Cd: 0.318633 | True Cd: 0.339085
# 🚗 DrivAer_F_D_WM_WW_0879 → Predicted Cd: 0.315329 | True Cd: 0.330856
# 🚗 DrivAer_F_D_WM_WW_1514 → Predicted Cd: 0.302768 | True Cd: 0.318153
# 🚗 DrivAer_F_D_WM_WW_2495 → Predicted Cd: 0.279931 | True Cd: 0.279199
# 🚗 DrivAer_F_D_WM_WW_1426 → Predicted Cd: 0.311012 | True Cd: 0.323044
# 🚗 DrivAer_F_D_WM_WW_2924 → Predicted Cd: 0.292033 | True Cd: 0.312536
# 🚗 DrivAer_F_D_WM_WW_2575 → Predicted Cd: 0.309831 | True Cd: 0.328359
# 🚗 DrivAer_F_D_WM_WW_2928 → Predicted Cd: 0.315624 | True Cd: 0.320004
# 🚗 DrivAer_F_D_WM_WW_2102 → Predicted Cd: 0.328125 | True Cd: 0.362431
# 🚗 DrivAer_F_D_WM_WW_0490 → Predicted Cd: 0.302156 | True Cd: 0.305766
# 🚗 DrivAer_F_D_WM_WW_2402 → Predicted Cd: 0.282428 | True Cd: 0.290973
# 🚗 DrivAer_F_D_WM_WW_0317 → Predicted Cd: 0.289384 | True Cd: 0.309008
# 🚗 DrivAer_F_D_WM_WW_0412 → Predicted Cd: 0.295813 | True Cd: 0.305758
# 🚗 DrivAer_F_D_WM_WW_1793 → Predicted Cd: 0.287821 | True Cd: 0.299640
# 🚗 DrivAer_F_D_WM_WW_1944 → Predicted Cd: 0.312511 | True Cd: 0.332290
# 🚗 DrivAer_F_D_WM_WW_3954 → Predicted Cd: 0.290052 | True Cd: 0.302433
# 🚗 DrivAer_F_D_WM_WW_1026 → Predicted Cd: 0.281960 | True Cd: 0.288365
# 🚗 DrivAer_F_D_WM_WW_0335 → Predicted Cd: 0.325891 | True Cd: 0.345044
# 🚗 DrivAer_F_D_WM_WW_3446 → Predicted Cd: 0.293557 | True Cd: 0.300111
# 🚗 DrivAer_F_D_WM_WW_0076 → Predicted Cd: 0.293228 | True Cd: 0.293605
# 🚗 DrivAer_F_D_WM_WW_3785 → Predicted Cd: 0.289058 | True Cd: 0.299768
# 🚗 DrivAer_F_D_WM_WW_1433 → Predicted Cd: 0.274052 | True Cd: 0.269937
# 🚗 DrivAer_F_D_WM_WW_2021 → Predicted Cd: 0.312444 | True Cd: 0.316442
# 🚗 DrivAer_F_D_WM_WW_1125 → Predicted Cd: 0.317372 | True Cd: 0.323182
# 🚗 DrivAer_F_D_WM_WW_2665 → Predicted Cd: 0.302682 | True Cd: 0.316093
# 🚗 DrivAer_F_D_WM_WW_2676 → Predicted Cd: 0.315771 | True Cd: 0.327918
# 🚗 DrivAer_F_D_WM_WW_1894 → Predicted Cd: 0.316148 | True Cd: 0.335237
# 🚗 DrivAer_F_D_WM_WW_3781 → Predicted Cd: 0.291058 | True Cd: 0.288810
# 🚗 DrivAer_F_D_WM_WW_1241 → Predicted Cd: 0.318324 | True Cd: 0.332423
# 🚗 DrivAer_F_D_WM_WW_3850 → Predicted Cd: 0.280307 | True Cd: 0.290384
# 🚗 DrivAer_F_D_WM_WW_2567 → Predicted Cd: 0.291074 | True Cd: 0.300456
# 🚗 DrivAer_F_D_WM_WW_0009 → Predicted Cd: 0.276539 | True Cd: 0.282641
# 🚗 DrivAer_F_D_WM_WW_3109 → Predicted Cd: 0.288287 | True Cd: 0.283313
# 🚗 DrivAer_F_D_WM_WW_0426 → Predicted Cd: 0.326057 | True Cd: 0.351838
# 🚗 DrivAer_F_D_WM_WW_1230 → Predicted Cd: 0.290862 | True Cd: 0.295772
# 🚗 DrivAer_F_D_WM_WW_0436 → Predicted Cd: 0.282141 | True Cd: 0.277422
# 🚗 DrivAer_F_D_WM_WW_2039 → Predicted Cd: 0.280749 | True Cd: 0.274604
# 🚗 DrivAer_F_D_WM_WW_0865 → Predicted Cd: 0.326238 | True Cd: 0.339895
# 🚗 DrivAer_F_D_WM_WW_3006 → Predicted Cd: 0.313317 | True Cd: 0.330179
# 🚗 DrivAer_F_D_WM_WW_0848 → Predicted Cd: 0.288066 | True Cd: 0.295582
# 🚗 DrivAer_F_D_WM_WW_2510 → Predicted Cd: 0.278871 | True Cd: 0.282399
# 🚗 DrivAer_F_D_WM_WW_0427 → Predicted Cd: 0.316026 | True Cd: 0.335077
# 🚗 DrivAer_F_D_WM_WW_0270 → Predicted Cd: 0.310708 | True Cd: 0.337168
# 🚗 DrivAer_F_D_WM_WW_2034 → Predicted Cd: 0.301067 | True Cd: 0.302347
# 🚗 DrivAer_F_D_WM_WW_1912 → Predicted Cd: 0.283675 | True Cd: 0.287513
# 🚗 DrivAer_F_D_WM_WW_1928 → Predicted Cd: 0.321096 | True Cd: 0.345816
# 🚗 DrivAer_F_D_WM_WW_0506 → Predicted Cd: 0.291974 | True Cd: 0.298776
# 🚗 DrivAer_F_D_WM_WW_0583 → Predicted Cd: 0.297332 | True Cd: 0.308742
# 🚗 DrivAer_F_D_WM_WW_2557 → Predicted Cd: 0.314535 | True Cd: 0.329115
# 🚗 DrivAer_F_D_WM_WW_3778 → Predicted Cd: 0.334061 | True Cd: 0.361512
# 🚗 DrivAer_F_D_WM_WW_0152 → Predicted Cd: 0.289581 | True Cd: 0.300749
# 🚗 DrivAer_F_D_WM_WW_2957 → Predicted Cd: 0.294732 | True Cd: 0.305333
# 🚗 DrivAer_F_D_WM_WW_1045 → Predicted Cd: 0.317277 | True Cd: 0.326679
# 🚗 DrivAer_F_D_WM_WW_0079 → Predicted Cd: 0.286361 | True Cd: 0.281329
# 🚗 DrivAer_F_D_WM_WW_1585 → Predicted Cd: 0.305460 | True Cd: 0.318813
# 🚗 DrivAer_F_D_WM_WW_1876 → Predicted Cd: 0.319891 | True Cd: 0.330842
# 🚗 DrivAer_F_D_WM_WW_3296 → Predicted Cd: 0.286498 | True Cd: 0.283449
# 🚗 DrivAer_F_D_WM_WW_1545 → Predicted Cd: 0.281941 | True Cd: 0.282853
# 🚗 DrivAer_F_D_WM_WW_2023 → Predicted Cd: 0.325778 | True Cd: 0.354952
# 🚗 DrivAer_F_D_WM_WW_0889 → Predicted Cd: 0.288659 | True Cd: 0.297103
# 🚗 DrivAer_F_D_WM_WW_2129 → Predicted Cd: 0.275972 | True Cd: 0.269539
# 🚗 DrivAer_F_D_WM_WW_2843 → Predicted Cd: 0.320557 | True Cd: 0.364616
# 🚗 DrivAer_F_D_WM_WW_1184 → Predicted Cd: 0.294609 | True Cd: 0.304453
# 🚗 DrivAer_F_D_WM_WW_0560 → Predicted Cd: 0.313310 | True Cd: 0.324086
# 🚗 DrivAer_F_D_WM_WW_1496 → Predicted Cd: 0.281268 | True Cd: 0.279361
# 🚗 DrivAer_F_D_WM_WW_1368 → Predicted Cd: 0.282278 | True Cd: 0.275281
# 🚗 DrivAer_F_D_WM_WW_2264 → Predicted Cd: 0.310348 | True Cd: 0.328729
# 🚗 DrivAer_F_D_WM_WW_0034 → Predicted Cd: 0.336396 | True Cd: 0.368110
# 🚗 DrivAer_F_D_WM_WW_2333 → Predicted Cd: 0.325113 | True Cd: 0.342289
#
# 📊 Evaluation Summary:
# 🔹 R² Score     : 0.8499
# 🔹 MSE          : 0.000210
# 🔹 MAE          : 0.011660
# 🔹 Cars tested  : 1158 / 1158
# 💾 Saved predictions to: ../outputs/eval/cd_predictions_test_design_ids.csv
